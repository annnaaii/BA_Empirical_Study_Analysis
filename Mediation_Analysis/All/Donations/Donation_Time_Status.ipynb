# %%
# Libraries
import pandas as pd
import numpy as np
from pyprocessmacro import Process
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)



import matplotlib.pyplot as plt

# %%
INPUT_PATH = "../../../Merging/Results/master_with_dv_means_recoded.csv"
df = pd.read_csv(INPUT_PATH)

# %%
# Controls

controls = ['Gender',
            'Age',
            'GeldProMonatKleidung',
            'GeldProMonat',
            'LikingMean',
            'IdentificationMean']

# %% [markdown]
# ### Output Code

# %% [markdown]
# ## Mall Donation Money Spendentafel

# %%
# Mall Data Set

m_d_t_df = df[df["Experiment_Type"] == "M_D_T"].copy()
m_d_s_t_df = df[df["Experiment_Type"] == "M_D_S_T"].copy()


columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Hippie0_Glam1': 'StyleGlam1Hippie0'
}

m_d_t_df  = m_d_t_df.rename(columns=columnNames)
m_d_s_t_df = m_d_s_t_df.rename(columns=columnNames)

vars_needed = [
    'StyleGlam1Hippie0',
    'DonationTime',
    'SocialStatusOld',
    'SocialStatusNew',
    'Spendentafel'
]

mall_dm = pd.concat([m_d_t_df, m_d_s_t_df], ignore_index=True)

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(mall_dm[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(mall_dm[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))


mall_donation_time_spendentafel = mall_dm[vars_needed].dropna().copy()

mall_donation_time_spendentafel.columns.tolist()
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam1Hippie0 ---
# StyleGlam1Hippie0
# 0    205
# 1    195
# Name: count, dtype: int64
#
# --- DonationTime ---
# DonationTime
# 0.0      63
# 150.0    43
# 30.0     36
# 60.0     29
# 80.0     17
#          ..
# 33.0      1
# 26.0      1
# 22.0      1
# 32.0      1
# 81.0      1
# Name: count, Length: 77, dtype: int64
#
# --- SocialStatusOld ---
# SocialStatusOld
# 3.67    61
# 4.00    60
# 3.33    59
# 3.00    48
# 2.67    44
# 2.33    35
# 4.33    27
# 2.00    20
# 4.67    13
# 5.00    11
# 1.67     8
# 1.00     8
# 1.33     6
# Name: count, dtype: int64
#
# --- SocialStatusNew ---
# SocialStatusNew
# 3.57    33
# 2.57    29
# 2.71    28
# 2.29    26
# 3.00    25
# 3.29    24
# 2.86    21
# 3.43    20
# 2.43    19
# 3.14    17
# 4.00    16
# 3.86    16
# 3.71    15
# 1.71    14
# 2.14    14
# 1.86    13
# 4.14    12
# 2.00    10
# 4.29     8
# 1.57     8
# 1.00     7
# 5.00     7
# 4.43     6
# 4.57     4
# 1.43     4
# ...

# %%
dir = "Tables/DonationTime/Spendentafel/Status/"

# %% [markdown]
# ## Model 4 - Without Moderation

# %%
p_old = Process(data = m_d_t_df, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], quantile=True)
p_old.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusOld", dir + "Model4")

p_new = Process(data = m_d_t_df, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusNew", dir + "Model4")
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam1Hippie0
#     y = DonationTime
#     m1 = SocialStatusOld
#
# Sample size:
# 185
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationTime
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0206   0.0043 2328.7526 1.9013    2  181   0.1523
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons               45.2989 14.4292  3.1394 0.0020  17.0182 73.5796
# StyleGlam1Hippie0 -13.6528  7.2422 -1.8852 0.0610 -27.8472  0.5416
# ...

# %% [markdown]
# ## Model 7 - Moderation on the A Path

# %%
p_old = Process(data = mall_donation_time_spendentafel, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_time_spendentafel, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam1Hippie0
#     y = DonationTime
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 399
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationTime
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0161   0.0086 2312.7071 3.2442    2  396   0.0400
#
# Coefficients
#
#                     coeff     se       t      p     LLCI    ULCI
# Cons              34.7049 9.4951  3.6550 0.0003  16.0948 53.3149
# StyleGlam1Hippie0 -6.1299 4.8635 -1.2604 0.2083 -15.6621  3.4023
# ...

# %% [markdown]
# ## Model 5 - Moderation on the C - Path

# %%
p_old = Process(data = mall_donation_time_spendentafel, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_time_spendentafel, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam1Hippie0
#     y = DonationTime
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 399
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationTime
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0267   0.0143 2299.4169 2.7037    4  394   0.0302
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            33.9876 10.1983  3.3327 0.0009  13.9994 53.9759
# ...

# %% [markdown]
# ## Process Model 8 - Moderation on the a and c path

# %%
p_old = Process(data = mall_donation_time_spendentafel, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_time_spendentafel, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam1Hippie0
#     y = DonationTime
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 399
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationTime
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0267   0.0143 2299.4169 2.7037    4  394   0.0302
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            33.9876 10.1983  3.3327 0.0009  13.9994 53.9759
# ...

# %% [markdown]
# ## Donation Money BeachBar Spendentafel

# %%
# BeachBar Data Set

bb_t_d_m = df[df["Experiment_Type"] == "BB_T_D_M"].copy()
bb_t_d_sm = df[df["Experiment_Type"] == "BB_T_D_SM"].copy()

columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Hippie0_Glam1': 'StyleGlam1Hippie0'
}

bb_t_d_m  = bb_t_d_m.rename(columns=columnNames)
bb_t_d_sm = bb_t_d_sm.rename(columns=columnNames)

vars_needed = [
    'StyleGlam1Hippie0',
    'SocialStatusOld',
    'SocialStatusNew',
    'Spendentafel',
    'DonationTime'
]

bb_df = pd.concat([bb_t_d_m, bb_t_d_sm], ignore_index=True)




bb_donation_money_spendentafel = bb_df[vars_needed].dropna().copy()

bb_donation_money_spendentafel.columns.tolist()

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(bb_donation_money_spendentafel[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(bb_df[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam1Hippie0 ---
# Series([], Name: count, dtype: int64)
#
# --- SocialStatusOld ---
# Series([], Name: count, dtype: int64)
#
# --- SocialStatusNew ---
# Series([], Name: count, dtype: int64)
#
# --- Spendentafel ---
# Series([], Name: count, dtype: int64)
#
# --- DonationTime ---
# Series([], Name: count, dtype: int64)
#
# === Missing values BEFORE dropna ===
# StyleGlam1Hippie0      0
# SocialStatusOld        0
# SocialStatusNew        0
# Spendentafel           0
# DonationTime         158
# dtype: int64
#
# === Total rows BEFORE dropna ===
# 400

# %% [markdown]
# ### Model 4

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 p_old = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], quantile=True)
#       2 p_old.summary()
#       4 p_new = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], quantile=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyprocessmacro/process.py:761, in Process.__init__(self, data, model, modval, cluster, boot, seed, mc, conf, effsize, jn, hc3, controls, controls_in, total, contrast, center, quantile, detail, percent, logit, iterate, convergence, precision, suppr_init, **kwargs)
#     758 self._symb_to_ind = {v: i for i, v in enumerate(self._data.columns.values)}
# ...

# %% [markdown]
# ### Model 7

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()

# %% [markdown]
# ### Model 5

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()

# %% [markdown]
# ### Model 8

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()

# %% [markdown]
# ## Donation Money Video - DO NOT EVALUATE NO NEED

# %% [markdown]
# ### Model 7

# %%
m_d_a_t_df = df[df["Experiment_Type"] == "M_D_A_T"].copy()
m_d_n_t_df = df[df["Experiment_Type"] == "M_D_N_T"].copy()

columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Awe_3cat': 'Video',
    'Style_Hippie0_Glam1': 'StyleGlam1Hippie0', 
}

m_d_a_t_df  = m_d_a_t_df.rename(columns=columnNames)
m_d_n_t_df = m_d_n_t_df.rename(columns=columnNames)
m_d_t_df = m_d_t_df.rename(columns={'Awe_3cat': 'Video'})


vars_needed = [
    'StyleGlam1Hippie0',
    'DonationTime',
    'SocialStatusOld',
    'SocialStatusNew',
    'Video'
]

m_d_a_t_df["Video"] = 1
m_d_n_t_df["Video"] = 0

mall_noVid_neutral_df = (pd.concat([m_d_t_df, m_d_n_t_df], ignore_index=True))[vars_needed].dropna().copy()


mall_donation_time_video_01_2 = (pd.concat([mall_noVid_neutral_df, m_d_a_t_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_0_2 = (pd.concat([m_d_t_df, m_d_a_t_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_1_2 = (pd.concat([m_d_a_t_df, m_d_n_t_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_time_video_01_2.columns.tolist()
mall_donation_money_video_1_2.columns.tolist()

for col in mall_donation_time_video_01_2.columns:
    print(f"\n===== Column: {col} =====")
    print("Unique values:")
    print(mall_donation_time_video_01_2[col].unique())

    print("\nValue counts:")
    print(mall_donation_time_video_01_2[col].value_counts(dropna=False))

    print("\n----------------------------")

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %% [markdown]
# ### Model 5

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 5, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %% [markdown]
# ### Model 8

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 8, x = 'StyleGlam1Hippie0', y = 'DonationTime', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
