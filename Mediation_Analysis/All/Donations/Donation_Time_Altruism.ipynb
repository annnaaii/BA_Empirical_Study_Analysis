# %%
# Libraries
import pandas as pd
import numpy as np
from pyprocessmacro import Process
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)



import matplotlib.pyplot as plt

# %%
INPUT_PATH = "../../../Merging/Results/master_with_dv_means_recoded.csv"
df = pd.read_csv(INPUT_PATH)

# %%
# Controls

controls = ['Gender',
            'Age',
            'GeldProMonatKleidung',
            'GeldProMonat',
            'LikingMean',
            'IdentificationMean']

# %% [markdown]
# ### Output Code

# %% [markdown]
# ## Mall Donation Time Spendentafel

# %%
# Mall Data Set

m_d_t_df = df[df["Experiment_Type"] == "M_D_T"].copy()
m_d_s_t_df = df[df["Experiment_Type"] == "M_D_S_T"].copy()


columnNames = {
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

m_d_t_df  = m_d_t_df.rename(columns=columnNames)
m_d_s_t_df = m_d_s_t_df.rename(columns=columnNames)

vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'Altruism'
    'Spendentafel'
]

mall_dm = pd.concat([m_d_t_df, m_d_s_t_df], ignore_index=True)

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(mall_dm[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(mall_dm[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))


mall_donation_time_spendentafel = mall_dm[vars_needed].dropna().copy()

mall_donation_time_spendentafel.columns.tolist()

# %%
dir = "Tables#/DonationMoney/Spendentafel/Altruism/"

# %% [markdown]
# ## Model 4 - Without Moderation

# %%
p_model4 = Process(data = m_d_t_df, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], quantile=True)
p_model4.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusOld", dir + "Model4")

# %% [markdown]
# ## Model 7 - Moderation on the A Path

# %%
p_model7 = Process(data = mall_donation_time_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w ='Spendentafel', quantile=True)
p_model7.summary()

# %% [markdown]
# ## Model 5 - Moderation on the C - Path

# %%
p_model5 = Process(data = mall_donation_time_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w ='Spendentafel', quantile=True)
p_model5.summary()

# %% [markdown]
# ## Process Model 8 - Moderation on the a and c path

# %%
p_model8 = Process(data = mall_donation_time_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Spendentafel'], quantile=True)
p_model8.summary()

# %% [markdown]
# ## Donation Money BeachBar Spendentafel

# %%
# BeachBar Data Set

bb_t_d_t = df[df["Experiment_Type"] == "BB_T_D_T"].copy()
bb_t_d_st = df[df["Experiment_Type"] == "BB_T_D_ST"].copy()

columnNames = {
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

bb_t_d_t  = bb_t_d_t.rename(columns=columnNames)
bb_t_d_st = bb_t_d_st.rename(columns=columnNames)

vars_needed = [
    'Altruism'
    'SocialStatusNew',
    'Spendentafel',
    'DonationMoney'
]

bb_df = pd.concat([bb_t_d_t, bb_t_d_st], ignore_index=True)




bb_donation_time_spendentafel = bb_df[vars_needed].dropna().copy()

bb_donation_time_spendentafel.columns.tolist()

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(bb_donation_time_spendentafel[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(bb_df[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))

# %% [markdown]
# ### Model 4

# %%
p_model4 = Process(data = bb_t_d_t, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], quantile=True)
p_model4.summary()

# %% [markdown]
# ### Model 7

# %%
p_model7 = Process(data = bb_donation_time_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Spendentafel'], quantile=True)
p_model7.summary()

# %% [markdown]
# ### Model 5

# %%
p_model5 = Process(data = bb_donation_time_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Spendentafel'], quantile=True)
p_model5.summary()

# %% [markdown]
# ### Model 8

# %%
p_model8= Process(data = bb_donation_time_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Spendentafel'], quantile=True)
p_model8.summary()

# %% [markdown]
# ## Donation Money Video

# %% [markdown]
# ### Model 7

# %%
m_d_a_t_df = df[df["Experiment_Type"] == "M_D_A_T"].copy()
m_d_n_t_df = df[df["Experiment_Type"] == "M_D_N_T"].copy()

columnNames = {
    'Awe_3cat': 'Video',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1', 
}

m_d_a_t_df  = m_d_a_t_df.rename(columns=columnNames)
m_d_n_t_df = m_d_n_t_df.rename(columns=columnNames)
m_d_t_df = m_d_t_df.rename(columns={'Awe_3cat': 'Video'})



vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'Altruism',
    'Video'
]

m_d_a_t_df["Video"] = 1
m_d_n_t_df["Video"] = 0


mall_noVid_neutral_df = (pd.concat([m_d_a_t_df, m_d_n_t_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_time_video_01_2 = (pd.concat([mall_noVid_neutral_df, m_d_a_m_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_0_2 = (pd.concat([m_d_t_df, m_d_a_t_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_1_2 = (pd.concat([m_d_a_t_df, m_d_n_t_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_time_video_01_2.columns.tolist()
mall_donation_money_video_1_2.columns.tolist()

for col in mall_donation_time_video_01_2.columns:
    print(f"\n===== Column: {col} =====")
    print("Unique values:")
    print(mall_donation_time_video_01_2[col].unique())

    print("\nValue counts:")
    print(mall_donation_time_video_01_2[col].value_counts(dropna=False))

    print("\n----------------------------")

# %% [markdown]
# ### Model 7

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()

# %% [markdown]
# ## Model 5

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['Altruism'], w =['Video'], quantile=True)
p_old.summary()
