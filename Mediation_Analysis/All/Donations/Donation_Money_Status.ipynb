# %%
# Libraries
import pandas as pd
import numpy as np
from pyprocessmacro import Process
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)



import matplotlib.pyplot as plt

# %%
INPUT_PATH = "../../../Merging/Results/master_with_dv_means_recoded.csv"
df = pd.read_csv(INPUT_PATH)

# %%
# Controls

controls = ['Gender',
            'Age',
            'GeldProMonatKleidung',
            'GeldProMonat',
            'LikingMean',
            'IdentificationMean']

# %% [markdown]
# ### Output Code

# %% [markdown]
# ## Mall Donation Money Spendentafel

# %%
# Mall Data Set

m_d_m_df = df[df["Experiment_Type"] == "M_D_M"].copy()
m_d_s_m_df = df[df["Experiment_Type"] == "M_D_S_M"].copy()


columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

m_d_m_df  = m_d_m_df.rename(columns=columnNames)
m_d_s_m_df = m_d_s_m_df.rename(columns=columnNames)

vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'SocialStatusOld',
    'SocialStatusNew',
    'Spendentafel'
]

mall_dm = pd.concat([m_d_m_df, m_d_s_m_df], ignore_index=True)

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(mall_dm[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(mall_dm[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))


mall_donation_money_spendentafel = mall_dm[vars_needed].dropna().copy()

mall_donation_money_spendentafel.columns.tolist()
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam0Hippie1 ---
# StyleGlam0Hippie1
# 1    273
# 0    258
# Name: count, dtype: int64
#
# --- DonationMoney ---
# DonationMoney
# 0.0     109
# 10.0     49
# 5.0      38
# 15.0     37
# 20.0     34
#        ...
# 42.0      1
# 89.0      1
# 83.0      1
# 18.0      1
# 91.0      1
# Name: count, Length: 81, dtype: int64
#
# --- SocialStatusOld ---
# SocialStatusOld
# 3.67    71
# 4.00    67
# 3.00    65
# 3.33    61
# 2.33    57
# 2.67    56
# 4.33    40
# 2.00    25
# 1.67    24
# 4.67    24
# 1.00    14
# 1.33    14
# 5.00    13
# Name: count, dtype: int64
#
# --- SocialStatusNew ---
# SocialStatusNew
# 3.00    42
# 2.71    38
# 3.43    32
# 3.57    28
# 2.29    27
# 2.43    25
# 2.14    24
# 3.71    24
# 4.00    22
# 2.00    22
# 2.57    21
# 3.86    21
# 1.86    20
# 3.14    20
# 1.71    19
# 3.29    16
# 2.86    15
# 1.57    15
# 4.29    15
# 4.14    13
# 1.43    12
# 4.43    12
# 1.29    10
# 1.00     8
# 5.00     7
# 4.57     7
# 1.14     6
# 4.86     5
# 4.71     5
# Name: count, dtype: int64
#
# --- Spendentafel ---
# Spendentafel
# 0.0    299
# 1.0    232
# Name: count, dtype: int64
#
# === Missing values BEFORE dropna ===
# StyleGlam0Hippie1    0
# DonationMoney        0
# SocialStatusOld      0
# SocialStatusNew      0
# Spendentafel         0
# dtype: int64
#
# === Total rows BEFORE dropna ===
# 531
# ['StyleGlam0Hippie1',
#  'DonationMoney',
#  'SocialStatusOld',
#  'SocialStatusNew',
#  'Spendentafel']

# %%
dir = "Tables/DonationMoney/Spendentafel/Status/"

# %% [markdown]
# ## Model 4 - Without Moderation

# %%
p_old = Process(data = m_d_m_df, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], quantile=True)
p_old.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusOld", dir + "Model4")

p_new = Process(data = m_d_m_df, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusNew", dir + "Model4")
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#
# Sample size:
# 299
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0334   0.0236 1678.9715 5.1167    2  296   0.0065
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               23.2994 9.1734  2.5399 0.0116   5.3199 41.2790
# StyleGlam0Hippie1 -10.4301 4.8869 -2.1343 0.0336 -20.0082 -0.8521
# SocialStatusOld     4.6129 2.5695  1.7953 0.0736  -0.4232  9.6491
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0586   0.0523 0.8562 18.4923    1  297   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.3154 0.0768 43.1446 0.0000  3.1648  3.4660
# StyleGlam0Hippie1 -0.4604 0.1071 -4.3003 0.0000 -0.6703 -0.2506
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -10.4301 4.8869 -2.1343 0.0336 -20.0082 -0.8521
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld -2.1240   1.5446   -5.6941    0.3659
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#
# Sample size:
# 299
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0307   0.0209 1683.6725 4.6892    2  296   0.0099
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               25.9257 8.8782  2.9201 0.0038   8.5247 43.3266
# StyleGlam0Hippie1 -10.1665 4.9932 -2.0360 0.0426 -19.9530 -0.3799
# SocialStatusNew     3.9933 2.5845  1.5451 0.1234  -1.0721  9.0588
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0958   0.0897 0.8487 31.4583    1  297   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1721 0.0765 41.4624 0.0000  3.0222  3.3221
# StyleGlam0Hippie1 -0.5979 0.1066 -5.6088 0.0000 -0.8069 -0.3890
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -10.1665 4.9932 -2.0360 0.0426 -19.9530 -0.3799
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew -2.3877   1.8835   -6.5478    0.9641

# %% [markdown]
# ## Model 7 - Moderation on the A Path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0336   0.0281 1650.1313 9.1797    2  528   0.0001
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               35.0905 6.8765  5.1029 0.0000  21.6128 48.5682
# StyleGlam0Hippie1 -13.9830 3.5987 -3.8856 0.0001 -21.0364 -6.9297
# SocialStatusOld     1.9003 1.9028  0.9987 0.3184  -1.8291  5.6297
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0535   0.0463 0.8522 9.9246    3  527   0.0000
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.3154 0.0767 43.2467 0.0000  3.1651  3.4656
# StyleGlam0Hippie1              -0.4604 0.1068 -4.3104 0.0000 -0.6698 -0.2511
# Spendentafel                    0.1034 0.1158  0.8925 0.3725 -0.1237  0.3304
# StyleGlam0Hippie1*Spendentafel  0.1955 0.1616  1.2096 0.2270 -0.1213  0.5122
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -13.9830 3.5987 -3.8856 0.0001 -21.0364 -6.9297
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld        0.0000 -0.8750   1.0414   -3.1458    1.0045
#   SocialStatusOld        1.0000 -0.5035   0.6755   -2.2893    0.4423
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusOld 0.3714   0.6139 -0.3528 2.4791
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0320   0.0265 1652.8215 8.7350    2  528   0.0002
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               39.2194 6.6156  5.9284 0.0000  26.2532 52.1857
# StyleGlam0Hippie1 -14.3528 3.6506 -3.9316 0.0001 -21.5078 -7.1978
# SocialStatusNew     0.7121 1.9283  0.3693 0.7120  -3.0673  4.4916
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0745   0.0674 0.8349 14.1339    3  527   0.0000
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.1721 0.0759 41.8038 0.0000  3.0234  3.3209
# StyleGlam0Hippie1              -0.5979 0.1057 -5.6550 0.0000 -0.8052 -0.3907
# Spendentafel                   -0.0055 0.1147 -0.0480 0.9618 -0.2302  0.2192
# StyleGlam0Hippie1*Spendentafel  0.2644 0.1600  1.6529 0.0989 -0.0491  0.5779
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -14.3528 3.6506 -3.9316 0.0001 -21.5078 -7.1978
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew        0.0000 -0.4258   1.3473   -3.1115    2.2252
#   SocialStatusNew        1.0000 -0.2375   0.7969   -2.0603    1.1631
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusNew 0.1883   0.6879 -0.8895 2.0804

# %% [markdown]
# ## Model 5 - Moderation on the C - Path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0366   0.0274 1651.2981 4.9933    4  526   0.0006
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            32.7702 7.1975  4.5530 0.0000  18.6633 46.8771
# StyleGlam0Hippie1              -11.7455 4.7844 -2.4549 0.0144 -21.1227 -2.3682
# Spendentafel                     6.4023 5.1030  1.2546 0.2102  -3.5994 16.4041
# StyleGlam0Hippie1*Spendentafel  -5.2267 7.1233 -0.7337 0.4634 -19.1880  8.7347
# SocialStatusOld                  1.7563 1.9175  0.9159 0.3601  -2.0020  5.5146
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0394   0.0358 0.8616 21.7030    1  529   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.3607 0.0578 58.1553 0.0000  3.2474  3.4739
# StyleGlam0Hippie1 -0.3755 0.0806 -4.6586 0.0000 -0.5334 -0.2175
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect     SE       t      p     LLCI    ULCI
#         0.0000 -11.7455 4.7844 -2.4549 0.0144 -21.1227 -2.3682
#         1.0000 -16.9721 5.3617 -3.1654 0.0016 -27.4809 -6.4634
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld -0.6594   0.8573   -2.5373    0.8676
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0353   0.0261 1653.5702 4.8058    4  526   0.0008
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            36.5075 7.0157  5.2037 0.0000  22.7570 50.2580
# StyleGlam0Hippie1              -12.1610 4.8461 -2.5094 0.0124 -21.6593 -2.6628
# Spendentafel                     6.5875 5.1027  1.2910 0.1973  -3.4136 16.5886
# StyleGlam0Hippie1*Spendentafel  -5.0572 7.1367 -0.7086 0.4789 -19.0449  8.9306
# SocialStatusNew                  0.6575 1.9386  0.3392 0.7346  -3.1421  4.4570
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0650   0.0615 0.8403 36.7750    1  529   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1697 0.0571 55.5423 0.0000  3.0579  3.2816
# StyleGlam0Hippie1 -0.4827 0.0796 -6.0642 0.0000 -0.6387 -0.3267
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect     SE       t      p     LLCI    ULCI
#         0.0000 -12.1610 4.8461 -2.5094 0.0124 -21.6593 -2.6628
#         1.0000 -17.2182 5.3802 -3.2003 0.0015 -27.7633 -6.6731
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew -0.3173   1.0953   -2.5447    1.7929

# %% [markdown]
# ## Process Model 8 - Moderation on the a and c path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0366   0.0274 1651.2981 4.9933    4  526   0.0006
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            32.7702 7.1975  4.5530 0.0000  18.6633 46.8771
# StyleGlam0Hippie1              -11.7455 4.7844 -2.4549 0.0144 -21.1227 -2.3682
# Spendentafel                     6.4023 5.1030  1.2546 0.2102  -3.5994 16.4041
# StyleGlam0Hippie1*Spendentafel  -5.2267 7.1233 -0.7337 0.4634 -19.1880  8.7347
# SocialStatusOld                  1.7563 1.9175  0.9159 0.3601  -2.0020  5.5146
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0535   0.0463 0.8522 9.9246    3  527   0.0000
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.3154 0.0767 43.2467 0.0000  3.1651  3.4656
# StyleGlam0Hippie1              -0.4604 0.1068 -4.3104 0.0000 -0.6698 -0.2511
# Spendentafel                    0.1034 0.1158  0.8925 0.3725 -0.1237  0.3304
# StyleGlam0Hippie1*Spendentafel  0.1955 0.1616  1.2096 0.2270 -0.1213  0.5122
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect     SE       t      p     LLCI    ULCI
#         0.0000 -11.7455 4.7844 -2.4549 0.0144 -21.1227 -2.3682
#         1.0000 -16.9721 5.3617 -3.1654 0.0016 -27.4809 -6.4634
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld        0.0000 -0.8087   1.0569   -3.1007    1.0991
#   SocialStatusOld        1.0000 -0.4654   0.6712   -2.2883    0.4825
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusOld 0.3433   0.6195 -0.3745 2.5073
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 531
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0353   0.0261 1653.5702 4.8058    4  526   0.0008
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            36.5075 7.0157  5.2037 0.0000  22.7570 50.2580
# StyleGlam0Hippie1              -12.1610 4.8461 -2.5094 0.0124 -21.6593 -2.6628
# Spendentafel                     6.5875 5.1027  1.2910 0.1973  -3.4136 16.5886
# StyleGlam0Hippie1*Spendentafel  -5.0572 7.1367 -0.7086 0.4789 -19.0449  8.9306
# SocialStatusNew                  0.6575 1.9386  0.3392 0.7346  -3.1421  4.4570
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0745   0.0674 0.8349 14.1339    3  527   0.0000
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.1721 0.0759 41.8038 0.0000  3.0234  3.3209
# StyleGlam0Hippie1              -0.5979 0.1057 -5.6550 0.0000 -0.8052 -0.3907
# Spendentafel                   -0.0055 0.1147 -0.0480 0.9618 -0.2302  0.2192
# StyleGlam0Hippie1*Spendentafel  0.2644 0.1600  1.6529 0.0989 -0.0491  0.5779
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect     SE       t      p     LLCI    ULCI
#         0.0000 -12.1610 4.8461 -2.5094 0.0124 -21.6593 -2.6628
#         1.0000 -17.2182 5.3802 -3.2003 0.0015 -27.7633 -6.6731
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew        0.0000 -0.3931   1.3588   -3.1126    2.2539
#   SocialStatusNew        1.0000 -0.2193   0.7974   -2.0515    1.1961
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusNew 0.1738   0.6961 -0.9314 2.1093

# %% [markdown]
# ## Donation Money BeachBar Spendentafel

# %%
# BeachBar Data Set

bb_t_d_m = df[df["Experiment_Type"] == "BB_T_D_M"].copy()
bb_t_d_sm = df[df["Experiment_Type"] == "BB_T_D_SM"].copy()

columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

bb_t_d_m  = bb_t_d_m.rename(columns=columnNames)
bb_t_d_sm = bb_t_d_sm.rename(columns=columnNames)

vars_needed = [
    'StyleGlam0Hippie1',
    'SocialStatusOld',
    'SocialStatusNew',
    'Spendentafel',
    'DonationMoney'
]

bb_df = pd.concat([bb_t_d_m, bb_t_d_sm], ignore_index=True)




bb_donation_money_spendentafel = bb_df[vars_needed].dropna().copy()

bb_donation_money_spendentafel.columns.tolist()

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(bb_donation_money_spendentafel[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(bb_df[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam0Hippie1 ---
# StyleGlam0Hippie1
# 1    83
# 0    75
# Name: count, dtype: int64
#
# --- SocialStatusOld ---
# SocialStatusOld
# 3.67    23
# 4.00    23
# 3.00    20
# 3.33    19
# 2.33    18
# 4.33    13
# 2.67    12
# 1.67     8
# 2.00     8
# 5.00     5
# 4.67     3
# 1.33     3
# 1.00     3
# Name: count, dtype: int64
#
# --- SocialStatusNew ---
# SocialStatusNew
# 3.29    13
# 2.00    13
# 2.86    11
# 3.86    11
# 3.14     9
# 4.00     9
# 2.14     8
# 2.43     8
# 3.57     8
# 2.29     7
# 3.00     7
# 3.71     7
# 2.57     7
# 1.71     6
# 3.43     5
# 1.29     5
# 2.71     4
# 1.86     4
# 4.43     3
# 4.14     3
# 1.57     3
# 4.86     1
# 4.71     1
# 1.00     1
# 1.43     1
# 1.14     1
# 5.00     1
# 4.29     1
# Name: count, dtype: int64
#
# --- Spendentafel ---
# Spendentafel
# 0.0    96
# 1.0    62
# Name: count, dtype: int64
#
# --- DonationMoney ---
# DonationMoney
# 0.0      15
# 50.0     14
# 30.0     12
# 20.0     12
# 15.0     11
# 5.0       9
# 150.0     8
# 10.0      7
# 75.0      6
# 80.0      5
# 100.0     5
# 25.0      4
# 76.0      3
# 21.0      2
# 74.0      2
# 78.0      2
# 9.0       2
# 16.0      2
# 26.0      1
# 72.0      1
# 120.0     1
# 67.0      1
# 3.0       1
# 128.0     1
# 105.0     1
# 32.0      1
# 130.0     1
# 35.0      1
# 86.0      1
# 41.0      1
# 83.0      1
# 85.0      1
# 81.0      1
# 108.0     1
# 87.0      1
# 60.0      1
# 71.0      1
# 24.0      1
# 13.0      1
# 82.0      1
# 42.0      1
# 70.0      1
# 116.0     1
# 103.0     1
# 46.0      1
# 31.0      1
# 101.0     1
# 69.0      1
# 33.0      1
# 57.0      1
# 54.0      1
# 11.0      1
# 58.0      1
# 99.0      1
# 40.0      1
# Name: count, dtype: int64
#
# === Missing values BEFORE dropna ===
# StyleGlam0Hippie1    0
# SocialStatusOld      0
# SocialStatusNew      0
# Spendentafel         0
# DonationMoney        0
# dtype: int64
#
# === Total rows BEFORE dropna ===
# 531

# %% [markdown]
# ### Model 4

# %%
p_old = Process(data = bb_t_d_m, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], quantile=True)
p_old.summary()

p_new = Process(data = bb_t_d_m, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#
# Sample size:
# 96
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0634   0.0329 1287.8982 3.1489    2   93   0.0475
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons               68.0680 13.8102  4.9288 0.0000  41.0006 95.1354
# StyleGlam0Hippie1 -16.0888  7.3923 -2.1764 0.0321 -30.5775 -1.6002
# SocialStatusOld    -5.8304  3.8435 -1.5169 0.1327 -13.3635  1.7027
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0163  -0.0049 0.9275 1.5571    1   94   0.2152
#
# Coefficients
#
#                     coeff     se       t      p    LLCI   ULCI
# Cons               3.3189 0.1420 23.3736 0.0000  3.0406 3.5972
# StyleGlam0Hippie1 -0.2455 0.1968 -1.2478 0.2152 -0.6311 0.1401
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -16.0888 7.3923 -2.1764 0.0321 -30.5775 -1.6002
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld  1.4314   1.7114   -0.5035    7.0575
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#
# Sample size:
# 96
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0572   0.0264 1296.4995 2.8195    2   93   0.0647
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons               65.6621 14.1503  4.6403 0.0000  37.9280 93.3961
# StyleGlam0Hippie1 -17.0519  7.5862 -2.2478 0.0270 -31.9205 -2.1832
# SocialStatusNew    -5.4336  4.2061 -1.2918 0.1996 -13.6774  2.8102
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0597   0.0395 0.7796 5.9678    1   94   0.0164
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1185 0.1302 23.9540 0.0000  2.8633  3.3736
# StyleGlam0Hippie1 -0.4407 0.1804 -2.4429 0.0164 -0.7942 -0.0871
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -17.0519 7.5862 -2.2478 0.0270 -31.9205 -2.1832
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew  2.3945   2.5808   -1.0867    9.6565

# %% [markdown]
# ### Model 7

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0583   0.0400 1592.7823 4.7981    2  155   0.0095
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons               65.7730 12.5082  5.2584 0.0000  41.2574 90.2886
# StyleGlam0Hippie1 -19.6904  6.4136 -3.0701 0.0025 -32.2607 -7.1200
# SocialStatusOld    -2.8395  3.4979 -0.8118 0.4182  -9.6952  4.0162
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0173  -0.0084 0.8452 0.9043    3  154   0.4406
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI   ULCI
# Cons                            3.3189 0.1356 24.4845 0.0000  3.0532 3.5846
# StyleGlam0Hippie1              -0.2455 0.1878 -1.3071 0.1931 -0.6136 0.1226
# Spendentafel                    0.0142 0.2180  0.0651 0.9482 -0.4131 0.4414
# StyleGlam0Hippie1*Spendentafel  0.0127 0.3001  0.0424 0.9663 -0.5754 0.6008
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -19.6904 6.4136 -3.0701 0.0025 -32.2607 -7.1200
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld        0.0000  0.6971   1.2428   -0.7375    4.8071
#   SocialStatusOld        1.0000  0.6610   1.2090   -0.7003    4.8233
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator   Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusOld -0.0361   1.3403 -3.4887 2.3882
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0576   0.0392 1593.9830 4.7361    2  155   0.0101
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons               64.8205 12.4185  5.2197 0.0000  40.4807 89.1602
# StyleGlam0Hippie1 -19.9684  6.4931 -3.0753 0.0025 -32.6946 -7.2422
# SocialStatusNew    -2.7535  3.7411 -0.7360 0.4628 -10.0860  4.5789
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0450   0.0200 0.7360 2.4179    3  154   0.0684
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.1185 0.1265 24.6537 0.0000  2.8706  3.3664
# StyleGlam0Hippie1              -0.4407 0.1753 -2.5143 0.0130 -0.7842 -0.0972
# Spendentafel                   -0.0937 0.2034 -0.4604 0.6459 -0.4923  0.3050
# StyleGlam0Hippie1*Spendentafel  0.2337 0.2800  0.8347 0.4052 -0.3151  0.7825
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -19.9684 6.4931 -3.0753 0.0025 -32.6946 -7.2422
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew        0.0000  1.2134   1.9918   -1.7666    6.4466
#   SocialStatusNew        1.0000  0.5698   1.3446   -0.8928    5.4252
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator   Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusNew -0.6436   1.6602 -6.6658 1.0965

# %% [markdown]
# ### Model 5

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0899   0.0600 1559.3863 3.7803    4  153   0.0058
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            58.3815 12.8788  4.5331 0.0000  33.1395 83.6235
# StyleGlam0Hippie1              -15.3723  8.1123 -1.8949 0.0600 -31.2721  0.5275
# Spendentafel                    19.7377  9.3634  2.1080 0.0367   1.3857 38.0897
# StyleGlam0Hippie1*Spendentafel -11.4467 12.8886 -0.8881 0.3759 -36.7078 13.8145
# SocialStatusOld                 -2.9118  3.4612 -0.8413 0.4015  -9.6957  3.8721
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0172   0.0045 0.8345 2.7263    1  156   0.1007
#
# Coefficients
#
#                     coeff     se       t      p    LLCI   ULCI
# Cons               3.3244 0.1055 31.5160 0.0000  3.1177 3.5311
# StyleGlam0Hippie1 -0.2403 0.1455 -1.6512 0.1007 -0.5255 0.0449
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect      SE       t      p     LLCI    ULCI
#         0.0000 -15.3723  8.1123 -1.8949 0.0600 -31.2721  0.5275
#         1.0000 -26.8189 10.0834 -2.6597 0.0087 -46.5821 -7.0558
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld  0.6997   1.0411   -0.6608    3.8631
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0888   0.0589 1561.2822 3.7293    4  153   0.0063
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            57.0722 12.9576  4.4045 0.0000  31.6758 82.4686
# StyleGlam0Hippie1              -15.8380  8.2366 -1.9229 0.0564 -31.9815  0.3054
# Spendentafel                    19.4455  9.3754  2.0741 0.0397   1.0700 37.8210
# StyleGlam0Hippie1*Spendentafel -10.8575 12.9255 -0.8400 0.4022 -36.1910 14.4760
# SocialStatusNew                 -2.6791  3.7114 -0.7219 0.4715  -9.9534  4.5952
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0404   0.0280 0.7301 6.5646    1  156   0.0113
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.0823 0.0987 31.2407 0.0000  2.8889  3.2756
# StyleGlam0Hippie1 -0.3488 0.1361 -2.5621 0.0113 -0.6156 -0.0820
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect      SE       t      p     LLCI    ULCI
#         0.0000 -15.8380  8.2366 -1.9229 0.0564 -31.9815  0.3054
#         1.0000 -26.6955 10.0866 -2.6466 0.0090 -46.4648 -6.9262
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew  0.9344   1.5854   -1.5294    5.1347

# %% [markdown]
# ### Model 8

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0899   0.0600 1559.3863 3.7803    4  153   0.0058
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            58.3815 12.8788  4.5331 0.0000  33.1395 83.6235
# StyleGlam0Hippie1              -15.3723  8.1123 -1.8949 0.0600 -31.2721  0.5275
# Spendentafel                    19.7377  9.3634  2.1080 0.0367   1.3857 38.0897
# StyleGlam0Hippie1*Spendentafel -11.4467 12.8886 -0.8881 0.3759 -36.7078 13.8145
# SocialStatusOld                 -2.9118  3.4612 -0.8413 0.4015  -9.6957  3.8721
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0173  -0.0084 0.8452 0.9043    3  154   0.4406
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI   ULCI
# Cons                            3.3189 0.1356 24.4845 0.0000  3.0532 3.5846
# StyleGlam0Hippie1              -0.2455 0.1878 -1.3071 0.1931 -0.6136 0.1226
# Spendentafel                    0.0142 0.2180  0.0651 0.9482 -0.4131 0.4414
# StyleGlam0Hippie1*Spendentafel  0.0127 0.3001  0.0424 0.9663 -0.5754 0.6008
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect      SE       t      p     LLCI    ULCI
#         0.0000 -15.3723  8.1123 -1.8949 0.0600 -31.2721  0.5275
#         1.0000 -26.8189 10.0834 -2.6597 0.0087 -46.5821 -7.0558
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld        0.0000  0.7149   1.2284   -0.7264    4.6490
#   SocialStatusOld        1.0000  0.6779   1.2482   -0.7040    4.9166
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator   Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusOld -0.0370   1.3472 -3.4229 2.4565
#
#
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Spendentafel
#
# Sample size:
# 158
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0888   0.0589 1561.2822 3.7293    4  153   0.0063
#
# Coefficients
#
#                                   coeff      se       t      p     LLCI    ULCI
# Cons                            57.0722 12.9576  4.4045 0.0000  31.6758 82.4686
# StyleGlam0Hippie1              -15.8380  8.2366 -1.9229 0.0564 -31.9815  0.3054
# Spendentafel                    19.4455  9.3754  2.0741 0.0397   1.0700 37.8210
# StyleGlam0Hippie1*Spendentafel -10.8575 12.9255 -0.8400 0.4022 -36.1910 14.4760
# SocialStatusNew                 -2.6791  3.7114 -0.7219 0.4715  -9.9534  4.5952
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0450   0.0200 0.7360 2.4179    3  154   0.0684
#
# Coefficients
#
#                                  coeff     se       t      p    LLCI    ULCI
# Cons                            3.1185 0.1265 24.6537 0.0000  2.8706  3.3664
# StyleGlam0Hippie1              -0.4407 0.1753 -2.5143 0.0130 -0.7842 -0.0972
# Spendentafel                   -0.0937 0.2034 -0.4604 0.6459 -0.4923  0.3050
# StyleGlam0Hippie1*Spendentafel  0.2337 0.2800  0.8347 0.4052 -0.3151  0.7825
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Spendentafel   Effect      SE       t      p     LLCI    ULCI
#         0.0000 -15.8380  8.2366 -1.9229 0.0564 -31.9815  0.3054
#         1.0000 -26.6955 10.0866 -2.6466 0.0090 -46.4648 -6.9262
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Spendentafel  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew        0.0000  1.1806   2.0051   -1.9601    6.4427
#   SocialStatusNew        1.0000  0.5544   1.3685   -0.8937    5.4770
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#      Moderator         Mediator   Index  Boot SE    LLCI   ULCI
#   Spendentafel  SocialStatusNew -0.6262   1.6512 -6.6142 1.1223

# %% [markdown]
# ## Donation Money Video

# %% [markdown]
# ### Model 7

# %%
m_d_a_m_df = df[df["Experiment_Type"] == "M_D_A_M"].copy()
m_d_n_m_df = df[df["Experiment_Type"] == "M_D_N_M"].copy()

columnNames = {
    'Social_Status_Old_1_3': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Awe_3cat': 'Video',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1', 
}

m_d_a_m_df  = m_d_a_m_df.rename(columns=columnNames)
m_d_n_m_df = m_d_n_m_df.rename(columns=columnNames)
m_d_m_df = m_d_m_df.rename(columns={'Awe_3cat': 'Video'})


m_d_n_m_df["Video"] = 0
m_d_a_m_df["Video"] = 1

vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'SocialStatusOld',
    'SocialStatusNew',
    'Video'
]

mall_noVid_neutral_df = (pd.concat([m_d_m_df, m_d_n_m_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_time_video_01_2 = (pd.concat([mall_noVid_neutral_df, m_d_a_m_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_0_2 = (pd.concat([m_d_m_df, m_d_a_m_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_1_2 = (pd.concat([m_d_a_m_df, m_d_n_m_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_time_video_01_2.columns.tolist()
mall_donation_money_video_1_2.columns.tolist()

for col in mall_donation_time_video_01_2.columns:
    print(f"\n===== Column: {col} =====")
    print("Unique values:")
    print(mall_donation_time_video_01_2[col].unique())

    print("\nValue counts:")
    print(mall_donation_time_video_01_2[col].value_counts(dropna=False))

    print("\n----------------------------")
# Out:
# ===== Column: StyleGlam0Hippie1 =====
# Unique values:
# [0 1]
#
# Value counts:
# StyleGlam0Hippie1
# 1    230
# 0    212
# Name: count, dtype: int64
#
# ----------------------------
#
# ===== Column: DonationMoney =====
# Unique values:
# [ 12.   0.  10.  50.  75. 150.  15. 110.  54. 105.  28.   3. 100.  38.
#   30.  43.   5.  40.  78.  20.   4.  60.  18.  24.  22.  45. 108.  14.
#    6.  56.  71.  27.   1.  81. 104.  90.  25.  86.  47.  52.  39.  82.
#   35.   2.  29.  33.  79.  48.  80.  21.  70.  51.  36.  49.  53.  65.
#   19.  42.  89.  83.   7. 148.  44. 107.  11. 130.  23. 101.  46.  37.
#   17.  69.  55.  41. 140.  99.]
#
# Value counts:
# DonationMoney
# 0.0      85
# 10.0     41
# 150.0    36
# 5.0      35
# 20.0     31
#          ..
# 49.0      1
# 53.0      1
# 65.0      1
# 90.0      1
# 99.0      1
# Name: count, Length: 76, dtype: int64
#
# ----------------------------
#
# ===== Column: SocialStatusOld =====
# Unique values:
# [3.33 4.   3.   1.67 2.33 3.67 2.67 2.   4.33 4.67 1.   5.   1.33]
#
# Value counts:
# SocialStatusOld
# 3.00    59
# 3.67    59
# 2.67    50
# 4.00    49
# 2.33    49
# 3.33    45
# 4.33    27
# 2.00    26
# 1.67    20
# 4.67    16
# 5.00    15
# 1.00    14
# 1.33    13
# Name: count, dtype: int64
#
# ----------------------------
#
# ===== Column: SocialStatusNew =====
# Unique values:
# [3.71 4.   3.   3.14 2.29 1.86 2.14 3.57 3.43 2.43 4.14 2.57 4.86 3.29
#  4.43 1.   2.   2.71 5.   1.71 1.57 1.29 3.86 4.71 1.43 2.86 1.14 4.57
#  4.29]
#
# Value counts:
# SocialStatusNew
# 3.00    40
# 2.14    25
# 2.00    24
# 2.29    22
# 3.57    22
# 1.86    21
# 3.43    21
# 3.71    19
# 2.71    19
# 3.29    19
# 2.43    18
# 2.57    18
# 3.14    16
# 3.86    15
# 1.71    15
# 4.00    15
# 4.14    13
# 2.86    12
# 5.00    12
# 1.29    11
# 4.43    11
# 1.57    10
# 1.43    10
# 1.00     8
# 1.14     7
# 4.57     6
# 4.71     5
# 4.29     5
# 4.86     3
# Name: count, dtype: int64
#
# ----------------------------
#
# ===== Column: Video =====
# Unique values:
# [0. 1.]
#
# Value counts:
# Video
# 0.0    368
# 1.0     74
# Name: count, dtype: int64
#
# ----------------------------

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... NoVideo and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.0666   0.0602 1769.8167 15.6629    2  439   0.0000
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               15.0643 7.6132  1.9787 0.0485   0.1427 29.9859
# StyleGlam0Hippie1 -12.5884 4.0974 -3.0723 0.0023 -20.6191 -4.5577
# SocialStatusOld     8.3502 2.1270  3.9259 0.0001   4.1815 12.5190
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0508   0.0421 0.8872 7.8154    3  438   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3224 0.0710 46.7949 0.0000  3.1832  3.4615
# StyleGlam0Hippie1       -0.4631 0.0983 -4.7116 0.0000 -0.6558 -0.2705
# Video                   -0.0635 0.1723 -0.3685 0.7126 -0.4012  0.2742
# StyleGlam0Hippie1*Video  0.3445 0.2401  1.4347 0.1521 -0.1261  0.8151
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -12.5884 4.0974 -3.0723 0.0023 -20.6191 -4.5577
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -3.8671   1.4394   -7.3110   -1.5643
#   SocialStatusOld 1.0000 -0.9906   2.1673   -6.2749    2.4993
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusOld 2.8766   2.2896 -0.9425 8.4865
#
#
# ..................... NoVideo and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.0619   0.0555 1778.6582 14.4939    2  439   0.0000
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               18.2479 7.3422  2.4854 0.0133   3.8575 32.6383
# StyleGlam0Hippie1 -11.6550 4.1885 -2.7826 0.0056 -19.8644 -3.4457
# SocialStatusNew     7.7099 2.1258  3.6268 0.0003   3.5434 11.8764
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0848   0.0765 0.8948 13.5343    3  438   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.1890 0.0713 44.7232 0.0000  3.0492  3.3287
# StyleGlam0Hippie1       -0.6108 0.0987 -6.1874 0.0000 -0.8043 -0.4173
# Video                   -0.0898 0.1730 -0.5190 0.6040 -0.4290  0.2493
# StyleGlam0Hippie1*Video  0.3008 0.2411  1.2476 0.2129 -0.1718  0.7735
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -11.6550 4.1885 -2.7826 0.0056 -19.8644 -3.4457
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -4.7092   1.6981   -8.6114   -1.7951
#   SocialStatusNew 1.0000 -2.3897   2.2536   -8.3465    0.9165
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusNew 2.3195   2.1519 -1.1386 7.7630

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... No and Awe Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.0690   0.0614 1862.2413 13.7114    2  370   0.0000
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               18.6013 8.4315  2.2062 0.0280   2.0758 35.1269
# StyleGlam0Hippie1 -14.8664 4.5658 -3.2560 0.0012 -23.8153 -5.9175
# SocialStatusOld     7.9177 2.3599  3.3550 0.0009   3.2923 12.5431
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0486   0.0382 0.8992 6.2812    3  369   0.0004
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3154 0.0787 42.1009 0.0000  3.1610  3.4697
# StyleGlam0Hippie1       -0.4604 0.1097 -4.1962 0.0000 -0.6755 -0.2454
# Video                   -0.0565 0.1766 -0.3199 0.7492 -0.4026  0.2896
# StyleGlam0Hippie1*Video  0.3418 0.2463  1.3876 0.1661 -0.1410  0.8246
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -14.8664 4.5658 -3.2560 0.0012 -23.8153 -5.9175
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -3.6456   1.5645   -7.3699   -1.1363
#   SocialStatusOld 1.0000 -0.9392   2.0771   -5.9227    2.4906
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusOld 2.7064   2.2988 -0.7457 8.9415
#
#
# ..................... No and Awe Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.0653   0.0577 1869.6428 12.9248    2  370   0.0000
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               21.4445 8.1311  2.6374 0.0087   5.5079 37.3811
# StyleGlam0Hippie1 -13.9820 4.6587 -3.0012 0.0029 -23.1129 -4.8510
# SocialStatusNew     7.3846 2.3654  3.1220 0.0019   2.7486 12.0207
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0797   0.0697 0.9014 10.6565    3  369   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.1721 0.0788 40.2332 0.0000  3.0176  3.3267
# StyleGlam0Hippie1       -0.5979 0.1099 -5.4425 0.0000 -0.8132 -0.3826
# Video                   -0.0730 0.1768 -0.4128 0.6800 -0.4195  0.2735
# StyleGlam0Hippie1*Video  0.2880 0.2466  1.1676 0.2437 -0.1954  0.7714
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -13.9820 4.6587 -3.0012 0.0029 -23.1129 -4.8510
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -4.4154   1.8254   -8.3934   -1.2882
#   SocialStatusNew 1.0000 -2.2889   2.2089   -8.2627    0.7335
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusNew 2.1265   2.1311 -1.0444 8.0234

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... Awe and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1648   0.1467 1869.9972 13.8096    2  140   0.0000
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons                0.9077 13.3521  0.0680 0.9459 -25.2620 27.0773
# StyleGlam0Hippie1 -18.9551  7.3290 -2.5863 0.0107 -33.3196 -4.5906
# SocialStatusOld    15.3580  3.7120  4.1373 0.0001   8.0825 22.6335
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0329   0.0049 0.9657 1.5771    3  139   0.1977
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3552 0.1765 19.0092 0.0000  3.0092  3.7011
# StyleGlam0Hippie1       -0.4783 0.2378 -2.0111 0.0462 -0.9445 -0.0122
# Video                   -0.0963 0.2408 -0.3998 0.6899 -0.5682  0.3757
# StyleGlam0Hippie1*Video  0.3597 0.3299  1.0904 0.2774 -0.2868  1.0062
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -18.9551 7.3290 -2.5863 0.0107 -33.3196 -4.5906
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -7.3460   3.5178  -15.6837   -1.4660
#   SocialStatusOld 1.0000 -1.8219   4.0861  -11.6680    4.6825
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI    ULCI
#      Video  SocialStatusOld 5.5242   4.9725 -4.1709 15.7247
#
#
# ..................... Awe and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1544   0.1361 1893.2452 12.7804    2  140   0.0000
#
# Coefficients
#
#                      coeff      se       t      p     LLCI    ULCI
# Cons                6.2415 12.8049  0.4874 0.6267 -18.8557 31.3387
# StyleGlam0Hippie1 -16.5470  7.5058 -2.2046 0.0291 -31.2580 -1.8359
# SocialStatusNew    14.2896  3.6666  3.8972 0.0002   7.1031 21.4760
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0643   0.0371 1.0045 3.1814    3  139   0.0260
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.2677 0.1800 18.1530 0.0000  2.9149  3.6206
# StyleGlam0Hippie1       -0.6735 0.2426 -2.7767 0.0062 -1.1490 -0.1981
# Video                   -0.1686 0.2456 -0.6864 0.4936 -0.6499  0.3127
# StyleGlam0Hippie1*Video  0.3636 0.3364  1.0807 0.2817 -0.2958  1.0229
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Direct effect of StyleGlam0Hippie1 on DonationMoney:
#
#    Effect     SE       t      p     LLCI    ULCI
#  -16.5470 7.5058 -2.2046 0.0291 -31.2580 -1.8359
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -9.6245   3.8006  -18.7641   -3.3627
#   SocialStatusNew 1.0000 -4.4291   4.2902  -15.5078    1.6027
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI    ULCI
#      Video  SocialStatusNew 5.1953   4.7780 -3.5217 15.5485

# %% [markdown]
# ### Model 5

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... NoVideo and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1056   0.0953 1703.6300 12.8995    4  437   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                      9.0411  7.6206  1.1864 0.2361  -5.8950  23.9771
# StyleGlam0Hippie1        -7.1583  4.4151 -1.6213 0.1057 -15.8118   1.4951
# Video                    32.9337  7.5512  4.3614 0.0000  18.1336  47.7337
# StyleGlam0Hippie1*Video -31.6310 10.5465 -2.9992 0.0029 -52.3017 -10.9603
# SocialStatusOld           8.4803  2.0938  4.0501 0.0001   4.3765  12.5841
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0444   0.0400 0.8891 20.4426    1  440   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.3116 0.0648 51.1359 0.0000  3.1847  3.4385
# StyleGlam0Hippie1 -0.4059 0.0898 -4.5213 0.0000 -0.5819 -0.2300
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -7.1583 4.4151 -1.6213 0.1057 -15.8118   1.4951
#  1.0000 -38.7893 9.6030 -4.0393 0.0001 -57.6108 -19.9679
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld -3.4422   1.3119   -6.6671   -1.3802
#
#
# ..................... NoVideo and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1014   0.0911 1711.5843 12.3318    4  437   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                     12.0187  7.3576  1.6335 0.1031  -2.4019  26.4394
# StyleGlam0Hippie1        -6.2596  4.5021 -1.3904 0.1651 -15.0835   2.5643
# Video                    33.1048  7.5700  4.3732 0.0000  18.2680  47.9417
# StyleGlam0Hippie1*Video -31.0867 10.5651 -2.9424 0.0034 -51.7938 -10.3796
# SocialStatusNew           7.9013  2.0897  3.7811 0.0002   3.8056  11.9971
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0810   0.0768 0.8945 38.7683    1  440   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1737 0.0650 48.8582 0.0000  3.0464  3.3010
# StyleGlam0Hippie1 -0.5607 0.0900 -6.2264 0.0000 -0.7372 -0.3842
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -6.2596 4.5021 -1.3904 0.1651 -15.0835   2.5643
#  1.0000 -37.3463 9.6439 -3.8725 0.0001 -56.2480 -18.4445
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew -4.4301   1.5706   -8.0773   -1.7875

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... No and Awe Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1077   0.0955 1794.5693 11.1023    4  368   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI    ULCI
# Cons                     11.9627  8.4750  1.4115 0.1589  -4.6480 28.5734
# StyleGlam0Hippie1        -8.8557  5.0176 -1.7649 0.0784 -18.6899  0.9786
# Video                    31.4718  7.8894  3.9891 0.0001  16.0088 46.9347
# StyleGlam0Hippie1*Video -29.9868 11.0334 -2.7178 0.0069 -51.6119 -8.3617
# SocialStatusOld           8.0324  2.3256  3.4538 0.0006   3.4742 12.5905
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0412   0.0360 0.9013 15.9447    1  371   0.0001
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.3041 0.0706 46.8240 0.0000  3.1658  3.4424
# StyleGlam0Hippie1 -0.3927 0.0984 -3.9931 0.0001 -0.5855 -0.2000
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -8.8557 5.0176 -1.7649 0.0784 -18.6899   0.9786
#  1.0000 -38.8425 9.8565 -3.9408 0.0001 -58.1609 -19.5241
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld -3.1546   1.3822   -6.5400   -0.9889
#
#
# ..................... No and Awe Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1043   0.0921 1801.3421 10.7147    4  368   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI    ULCI
# Cons                     14.6714  8.1804  1.7935 0.0737  -1.3620 30.7048
# StyleGlam0Hippie1        -8.0451  5.1045 -1.5761 0.1159 -18.0498  1.9596
# Video                    31.5683  7.9050  3.9935 0.0001  16.0748 47.0618
# StyleGlam0Hippie1*Video -29.4127 11.0458 -2.6628 0.0081 -51.0622 -7.7633
# SocialStatusNew           7.5412  2.3272  3.2405 0.0013   2.9800 12.1024
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0754   0.0704 0.9007 30.2579    1  371   0.0000
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1576 0.0705 44.7614 0.0000  3.0194  3.2959
# StyleGlam0Hippie1 -0.5409 0.0983 -5.5007 0.0000 -0.7336 -0.3481
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -8.0451 5.1045 -1.5761 0.1159 -18.0498   1.9596
#  1.0000 -37.4579 9.8975 -3.7846 0.0002 -56.8567 -18.0591
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew -4.0787   1.6624   -7.7632   -1.2946

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... Awe and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.2513   0.2240 1700.5939 11.5791    4  138   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                    -22.4615 14.0523 -1.5984 0.1122 -50.0036   5.0806
# StyleGlam0Hippie1         3.3152 10.1247  0.3274 0.7438 -16.5288  23.1592
# Video                    40.3645 10.1101  3.9925 0.0001  20.5490  60.1799
# StyleGlam0Hippie1*Video -41.2283 13.9011 -2.9658 0.0036 -68.4740 -13.9827
# SocialStatusOld          15.8668  3.5593  4.4579 0.0000   8.8907  22.8429
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0223   0.0083 0.9625 3.2170    1  141   0.0750
#
# Coefficients
#
#                     coeff     se       t      p    LLCI   ULCI
# Cons               3.3034 0.1199 27.5616 0.0000  3.0685 3.5383
# StyleGlam0Hippie1 -0.2949 0.1644 -1.7936 0.0750 -0.6171 0.0274
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect      SE       t      p     LLCI     ULCI
#  0.0000   3.3152 10.1247  0.3274 0.7438 -16.5288  23.1592
#  1.0000 -37.9131  9.6005 -3.9491 0.0001 -56.7297 -19.0965
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld -4.6788   2.8752  -11.7280    0.0333
#
#
# ..................... Awe and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.2451   0.2176 1714.6342 11.2018    4  138   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                    -18.5849 13.6542 -1.3611 0.1757 -45.3467   8.1769
# StyleGlam0Hippie1         5.8995 10.2958  0.5730 0.5676 -14.2799  26.0789
# Video                    41.3832 10.1631  4.0719 0.0001  21.4639  61.3025
# StyleGlam0Hippie1*Video -41.0129 13.9573 -2.9385 0.0039 -68.3688 -13.6571
# SocialStatusNew          15.1050  3.5043  4.3104 0.0000   8.2367  21.9732
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0562   0.0428 0.9988 8.4021    1  141   0.0043
#
# Coefficients
#
#                     coeff     se       t      p    LLCI    ULCI
# Cons               3.1772 0.1221 26.0224 0.0000  2.9379  3.4165
# StyleGlam0Hippie1 -0.4855 0.1675 -2.8986 0.0043 -0.8137 -0.1572
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect      SE       t      p     LLCI     ULCI
#  0.0000   5.8995 10.2958  0.5730 0.5676 -14.2799  26.0789
#  1.0000 -35.1134  9.6918 -3.6230 0.0004 -54.1090 -16.1179
#
# Indirect effect of StyleGlam0Hippie1 on DonationMoney:
#
#                    Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew -7.3328   3.2046  -15.0179   -2.2656

# %% [markdown]
# ### Model 8

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... NoVideo and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1056   0.0953 1703.6300 12.8995    4  437   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                      9.0411  7.6206  1.1864 0.2361  -5.8950  23.9771
# StyleGlam0Hippie1        -7.1583  4.4151 -1.6213 0.1057 -15.8118   1.4951
# Video                    32.9337  7.5512  4.3614 0.0000  18.1336  47.7337
# StyleGlam0Hippie1*Video -31.6310 10.5465 -2.9992 0.0029 -52.3017 -10.9603
# SocialStatusOld           8.4803  2.0938  4.0501 0.0001   4.3765  12.5841
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0508   0.0421 0.8872 7.8154    3  438   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3224 0.0710 46.7949 0.0000  3.1832  3.4615
# StyleGlam0Hippie1       -0.4631 0.0983 -4.7116 0.0000 -0.6558 -0.2705
# Video                   -0.0635 0.1723 -0.3685 0.7126 -0.4012  0.2742
# StyleGlam0Hippie1*Video  0.3445 0.2401  1.4347 0.1521 -0.1261  0.8151
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -7.1583 4.4151 -1.6213 0.1057 -15.8118   1.4951
#  1.0000 -38.7893 9.6030 -4.0393 0.0001 -57.6108 -19.9679
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -3.9274   1.4600   -7.3664   -1.6048
#   SocialStatusOld 1.0000 -1.0060   2.1210   -5.9295    2.6765
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusOld 2.9214   2.4053 -0.9254 8.9616
#
#
# ..................... NoVideo and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 442
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1014   0.0911 1711.5843 12.3318    4  437   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                     12.0187  7.3576  1.6335 0.1031  -2.4019  26.4394
# StyleGlam0Hippie1        -6.2596  4.5021 -1.3904 0.1651 -15.0835   2.5643
# Video                    33.1048  7.5700  4.3732 0.0000  18.2680  47.9417
# StyleGlam0Hippie1*Video -31.0867 10.5651 -2.9424 0.0034 -51.7938 -10.3796
# SocialStatusNew           7.9013  2.0897  3.7811 0.0002   3.8056  11.9971
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0848   0.0765 0.8948 13.5343    3  438   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.1890 0.0713 44.7232 0.0000  3.0492  3.3287
# StyleGlam0Hippie1       -0.6108 0.0987 -6.1874 0.0000 -0.8043 -0.4173
# Video                   -0.0898 0.1730 -0.5190 0.6040 -0.4290  0.2493
# StyleGlam0Hippie1*Video  0.3008 0.2411  1.2476 0.2129 -0.1718  0.7735
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -6.2596 4.5021 -1.3904 0.1651 -15.0835   2.5643
#  1.0000 -37.3463 9.6439 -3.8725 0.0001 -56.2480 -18.4445
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -4.8261   1.6990   -8.7572   -1.9546
#   SocialStatusNew 1.0000 -2.4491   2.1598   -7.8903    0.9491
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusNew 2.3771   2.2556 -1.1387 8.0648

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... No and Awe Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1077   0.0955 1794.5693 11.1023    4  368   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI    ULCI
# Cons                     11.9627  8.4750  1.4115 0.1589  -4.6480 28.5734
# StyleGlam0Hippie1        -8.8557  5.0176 -1.7649 0.0784 -18.6899  0.9786
# Video                    31.4718  7.8894  3.9891 0.0001  16.0088 46.9347
# StyleGlam0Hippie1*Video -29.9868 11.0334 -2.7178 0.0069 -51.6119 -8.3617
# SocialStatusOld           8.0324  2.3256  3.4538 0.0006   3.4742 12.5905
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0486   0.0382 0.8992 6.2812    3  369   0.0004
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3154 0.0787 42.1009 0.0000  3.1610  3.4697
# StyleGlam0Hippie1       -0.4604 0.1097 -4.1962 0.0000 -0.6755 -0.2454
# Video                   -0.0565 0.1766 -0.3199 0.7492 -0.4026  0.2896
# StyleGlam0Hippie1*Video  0.3418 0.2463  1.3876 0.1661 -0.1410  0.8246
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -8.8557 5.0176 -1.7649 0.0784 -18.6899   0.9786
#  1.0000 -38.8425 9.8565 -3.9408 0.0001 -58.1609 -19.5241
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -3.6985   1.5972   -7.6229   -1.1667
#   SocialStatusOld 1.0000 -0.9528   2.0226   -5.4645    2.6588
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusOld 2.7456   2.4278 -0.7201 9.6066
#
#
# ..................... No and Awe Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 373
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.1043   0.0921 1801.3421 10.7147    4  368   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI    ULCI
# Cons                     14.6714  8.1804  1.7935 0.0737  -1.3620 30.7048
# StyleGlam0Hippie1        -8.0451  5.1045 -1.5761 0.1159 -18.0498  1.9596
# Video                    31.5683  7.9050  3.9935 0.0001  16.0748 47.0618
# StyleGlam0Hippie1*Video -29.4127 11.0458 -2.6628 0.0081 -51.0622 -7.7633
# SocialStatusNew           7.5412  2.3272  3.2405 0.0013   2.9800 12.1024
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE       F  df1  df2  p-value
#  0.0797   0.0697 0.9014 10.6565    3  369   0.0000
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.1721 0.0788 40.2332 0.0000  3.0176  3.3267
# StyleGlam0Hippie1       -0.5979 0.1099 -5.4425 0.0000 -0.8132 -0.3826
# Video                   -0.0730 0.1768 -0.4128 0.6800 -0.4195  0.2735
# StyleGlam0Hippie1*Video  0.2880 0.2466  1.1676 0.2437 -0.1954  0.7714
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect     SE       t      p     LLCI     ULCI
#  0.0000  -8.0451 5.1045 -1.5761 0.1159 -18.0498   1.9596
#  1.0000 -37.4579 9.8975 -3.7846 0.0002 -56.8567 -18.0591
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -4.5090   1.8316   -8.6584   -1.4499
#   SocialStatusNew 1.0000 -2.3374   2.0910   -7.8372    0.7094
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI   ULCI
#      Video  SocialStatusNew 2.1716   2.2253 -0.9725 8.4465

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... Awe and Neutral Video, Status Old .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.2513   0.2240 1700.5939 11.5791    4  138   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                    -22.4615 14.0523 -1.5984 0.1122 -50.0036   5.0806
# StyleGlam0Hippie1         3.3152 10.1247  0.3274 0.7438 -16.5288  23.1592
# Video                    40.3645 10.1101  3.9925 0.0001  20.5490  60.1799
# StyleGlam0Hippie1*Video -41.2283 13.9011 -2.9658 0.0036 -68.4740 -13.9827
# SocialStatusOld          15.8668  3.5593  4.4579 0.0000   8.8907  22.8429
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusOld
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0329   0.0049 0.9657 1.5771    3  139   0.1977
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.3552 0.1765 19.0092 0.0000  3.0092  3.7011
# StyleGlam0Hippie1       -0.4783 0.2378 -2.0111 0.0462 -0.9445 -0.0122
# Video                   -0.0963 0.2408 -0.3998 0.6899 -0.5682  0.3757
# StyleGlam0Hippie1*Video  0.3597 0.3299  1.0904 0.2774 -0.2868  1.0062
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect      SE       t      p     LLCI     ULCI
#  0.0000   3.3152 10.1247  0.3274 0.7438 -16.5288  23.1592
#  1.0000 -37.9131  9.6005 -3.9491 0.0001 -56.7297 -19.0965
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video  Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusOld 0.0000 -7.5894   3.8020  -16.7585   -1.2509
#   SocialStatusOld 1.0000 -1.8822   4.0646  -10.9875    5.2783
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI    ULCI
#      Video  SocialStatusOld 5.7072   5.4095 -4.2753 17.7455
#
#
# ..................... Awe and Neutral Video, Status New .....................
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusNew
#     w = Video
#
# Sample size:
# 143
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE       F  df1  df2  p-value
#  0.2451   0.2176 1714.6342 11.2018    4  138   0.0000
#
# Coefficients
#
#                            coeff      se       t      p     LLCI     ULCI
# Cons                    -18.5849 13.6542 -1.3611 0.1757 -45.3467   8.1769
# StyleGlam0Hippie1         5.8995 10.2958  0.5730 0.5676 -14.2799  26.0789
# Video                    41.3832 10.1631  4.0719 0.0001  21.4639  61.3025
# StyleGlam0Hippie1*Video -41.0129 13.9573 -2.9385 0.0039 -68.3688 -13.6571
# SocialStatusNew          15.1050  3.5043  4.3104 0.0000   8.2367  21.9732
#
# -------------------------------------------------------------------------
#
# Outcome = SocialStatusNew
# OLS Regression Summary
#
#      R²  Adj. R²    MSE      F  df1  df2  p-value
#  0.0643   0.0371 1.0045 3.1814    3  139   0.0260
#
# Coefficients
#
#                           coeff     se       t      p    LLCI    ULCI
# Cons                     3.2677 0.1800 18.1530 0.0000  2.9149  3.6206
# StyleGlam0Hippie1       -0.6735 0.2426 -2.7767 0.0062 -1.1490 -0.1981
# Video                   -0.1686 0.2456 -0.6864 0.4936 -0.6499  0.3127
# StyleGlam0Hippie1*Video  0.3636 0.3364  1.0807 0.2817 -0.2958  1.0229
#
# -------------------------------------------------------------------------
#
#
# ********************** DIRECT AND INDIRECT EFFECTS **********************
#
# Conditional direct effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#   Video   Effect      SE       t      p     LLCI     ULCI
#  0.0000   5.8995 10.2958  0.5730 0.5676 -14.2799  26.0789
#  1.0000 -35.1134  9.6918 -3.6230 0.0004 -54.1090 -16.1179
#
# Conditional indirect effect(s) of StyleGlam0Hippie1 on DonationMoney at values of the moderator(s):
#
#          Mediator  Video   Effect  Boot SE  BootLLCI  BootULCI
#   SocialStatusNew 0.0000 -10.1737   4.1202  -20.2835   -3.5029
#   SocialStatusNew 1.0000  -4.6819   4.1940  -14.7917    1.9346
#
# **************** INDEX OF MODERATED MEDIATION ******************
#
#  Moderator         Mediator  Index  Boot SE    LLCI    ULCI
#      Video  SocialStatusNew 5.4918   5.2828 -3.8322 17.4614

# %% [markdown]
# ### Model 14

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... NoVideo and Neutral Video, Status Old .....................
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 4
#       1 # No and Neutral
#       3 print("..................... NoVideo and Neutral Video, Status Old .....................")
# ----> 4 p_old = Process(data = mall_donation_time_video_01_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
#       5 p_old.summary()
#       7 print("..................... NoVideo and Neutral Video, Status New .....................")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyprocessmacro/process.py:728, in Process.__init__(self, data, model, modval, cluster, boot, seed, mc, conf, effsize, jn, hc3, controls, controls_in, total, contrast, center, quantile, detail, percent, logit, iterate, convergence, precision, suppr_init, **kwargs)
#     725 self.mediators = var_kwargs.get("m")
#     726 self.iv = var_kwargs.get("y")
# --> 728 self.varlist = self._gen_valid_varlist(var_kwargs)
#     730 # Check the number of mediators supplied to the model:
#     731 if self.model_num > 3:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyprocessmacro/process.py:871, in Process._gen_valid_varlist(self, var_kwargs)
#     869     if exced_vars:
#     870         err_str += f"Variable(s) supplied not supported by the model: {', '.join(exced_vars)}"
# --> 871     raise ValueError(err_str)
#     873 var_kwargs_names = []
#     874 for _, v in var_kwargs.items():
#
# ValueError: The variables supplied do not match the definition of Model 14
#             Expected variable(s) not supplied: vVariable(s) supplied not supported by the model: w

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 14, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %% [markdown]
# ### Model 15

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_time_video_01_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_time_video_01_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 15, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
