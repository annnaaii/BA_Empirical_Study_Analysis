# %%
# Libraries
import pandas as pd
import numpy as np
from pyprocessmacro import Process
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=FutureWarning)



import matplotlib.pyplot as plt

# %%
INPUT_PATH = "../../../Merging/Results/master_with_dv_means_recoded.csv"
df = pd.read_csv(INPUT_PATH)

# %%
# Controls

controls = ['Gender',
            'Age',
            'GeldProMonatKleidung',
            'GeldProMonat',
            'LikingMean',
            'IdentificationMean']

# %% [markdown]
# ### Output Code

# %% [markdown]
# ## Mall Donation Money Spendentafel

# %%
# Mall Data Set

m_d_m_df = df[df["Experiment_Type"] == "M_D_M"].copy()
m_d_s_m_df = df[df["Experiment_Type"] == "M_D_S_M"].copy()


columnNames = {
    'Social_Status_Old_1_4': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

m_d_m_df  = m_d_m_df.rename(columns=columnNames)
m_d_s_m_df = m_d_s_m_df.rename(columns=columnNames)

vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'SocialStatusOld',
    'SocialStatusNew',
    'Spendentafel'
]

mall_dm = pd.concat([m_d_m_df, m_d_s_m_df], ignore_index=True)

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(mall_dm[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(mall_dm[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))


mall_donation_money_spendentafel = mall_dm[vars_needed].dropna().copy()

mall_donation_money_spendentafel.columns.tolist()
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam0Hippie1 ---
# StyleGlam0Hippie1
# 1    268
# 0    248
# Name: count, dtype: int64
#
# --- DonationMoney ---
# DonationMoney
# 0.0     108
# 10.0     48
# 15.0     36
# 5.0      36
# 20.0     34
#        ...
# 65.0      1
# 43.0      1
# 42.0      1
# 86.0      1
# 52.0      1
# Name: count, Length: 79, dtype: int64
#
# --- SocialStatusOld ---
# SocialStatusOld
# 3.00    58
# 3.75    52
# 4.00    48
# 3.50    46
# 3.25    46
# 2.50    42
# 2.75    36
# 2.25    35
# 2.00    34
# 4.25    21
# 1.75    20
# 4.50    19
# 4.75    13
# 1.00    13
# 1.50    13
# 5.00    10
# 1.25    10
# Name: count, dtype: int64
#
# --- SocialStatusNew ---
# SocialStatusNew
# 3.00    42
# 2.71    35
# 3.43    31
# 3.57    28
# 2.29    26
# 2.43    24
# 3.71    24
# 2.14    22
# 4.00    22
# 3.86    21
# 1.86    20
# 3.14    20
# 2.00    20
# 2.57    19
# 1.71    19
# 3.29    16
# 2.86    15
# 4.29    15
# 1.57    14
# 1.43    12
# 4.14    12
# ...

# %%
dir = "Tables/Mall/DonationMoney/Spendentafel/"

# %% [markdown]
# ## Model 4 - Without Moderation

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], quantile=True)
p_old.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusOld", dir + "Model4")

p_new = Process(data = mall_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
#export_process_to_csv(p_old, "Mall_Model4_StatusNew", dir + "Model4")
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 4
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0300   0.0243 1632.3798 7.9330    2  513   0.0004
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               31.9117 6.8658  4.6479 0.0000  18.4550 45.3684
# StyleGlam0Hippie1 -12.4192 3.6400 -3.4118 0.0007 -19.5535 -5.2848
# ...

# %% [markdown]
# ## Model 7 - Moderation on the A Path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0300   0.0243 1632.3798 7.9330    2  513   0.0004
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               31.9117 6.8658  4.6479 0.0000  18.4550 45.3684
# StyleGlam0Hippie1 -12.4192 3.6400 -3.4118 0.0007 -19.5535 -5.2848
# ...

# %% [markdown]
# ## Model 5 - Moderation on the C - Path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w ='Spendentafel', quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w ='Spendentafel', quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0307   0.0212 1637.5754 4.0470    4  511   0.0031
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            30.9206 7.1934  4.2985 0.0000  16.8219 45.0194
# ...

# %% [markdown]
# ## Process Model 8 - Moderation on the a and c path

# %%
p_old = Process(data = mall_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = mall_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0307   0.0212 1637.5754 4.0470    4  511   0.0031
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            30.9206 7.1934  4.2985 0.0000  16.8219 45.0194
# ...

# %% [markdown]
# ## Donation Money BeachBar Spendentafel

# %%
# BeachBar Data Set

bb_t_d_m = df[df["Experiment_Type"] == "BB_T_D_M"].copy()
bb_t_d_sm = df[df["Experiment_Type"] == "BB_T_D_SM"].copy()

columnNames = {
    'Social_Status_Old_1_4': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Visibility_0_Private_1_Public': 'Spendentafel',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1'
}

bb_t_d_m  = bb_t_d_m.rename(columns=columnNames)
bb_t_d_sm = bb_t_d_sm.rename(columns=columnNames)

vars_needed = [
    'StyleGlam0Hippie1',
    'SocialStatusOld',
    'SocialStatusNew'
]

bb_df = pd.concat([bb_t_d_m, bb_t_d_sm], ignore_index=True)

# Inspect raw values BEFORE dropna()
print("=== Raw value counts BEFORE dropna ===\n")

for col in vars_needed:
    print(f"\n--- {col} ---")
    print(bb_df[col].value_counts(dropna=False))

print("\n=== Missing values BEFORE dropna ===")
print(bb_df[vars_needed].isna().sum())
print("\n=== Total rows BEFORE dropna ===")
print(len(mall_dm))


bb_donation_money_spendentafel = bb_df[vars_needed].dropna().copy()

bb_donation_money_spendentafel.columns.tolist()
# Out:
# === Raw value counts BEFORE dropna ===
#
#
# --- StyleGlam0Hippie1 ---
# StyleGlam0Hippie1
# 1    83
# 0    75
# Name: count, dtype: int64
#
# --- SocialStatusOld ---
# SocialStatusOld
# 2.75    21
# 3.25    19
# 4.00    17
# 3.75    16
# 2.25    15
# 3.00    11
# 4.25    11
# 2.50     9
# 3.50     8
# 2.00     7
# 1.50     6
# 1.75     5
# 5.00     4
# 4.50     3
# 1.25     3
# 4.75     2
# 1.00     1
# Name: count, dtype: int64
#
# --- SocialStatusNew ---
# SocialStatusNew
# 3.29    13
# 2.00    13
# 2.86    11
# 3.86    11
# 3.14     9
# 4.00     9
# 2.14     8
# 2.43     8
# 3.57     8
# 2.29     7
# 3.00     7
# 3.71     7
# 2.57     7
# 1.71     6
# 3.43     5
# 1.29     5
# 2.71     4
# 1.86     4
# 4.43     3
# 4.14     3
# 1.57     3
# 4.86     1
# 4.71     1
# 1.00     1
# 1.43     1
# 1.14     1
# 5.00     1
# 4.29     1
# Name: count, dtype: int64
#
# --- Spendentafel ---
# Spendentafel
# 0.0    96
# 1.0    62
# Name: count, dtype: int64
#
# ...

# %% [markdown]
# ### Model 4

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], quantile=True)
p_new.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 p_old = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], quantile=True)
#       2 p_old.summary()
#       4 p_new = Process(data = bb_donation_money_spendentafel, model = 4, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], quantile=True)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pyprocessmacro/process.py:728, in Process.__init__(self, data, model, modval, cluster, boot, seed, mc, conf, effsize, jn, hc3, controls, controls_in, total, contrast, center, quantile, detail, percent, logit, iterate, convergence, precision, suppr_init, **kwargs)
#     725 self.mediators = var_kwargs.get("m")
#     726 self.iv = var_kwargs.get("y")
# ...

# %% [markdown]
# ### Model 7

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 7
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0300   0.0243 1632.3798 7.9330    2  513   0.0004
#
# Coefficients
#
#                      coeff     se       t      p     LLCI    ULCI
# Cons               31.9117 6.8658  4.6479 0.0000  18.4550 45.3684
# StyleGlam0Hippie1 -12.4192 3.6400 -3.4118 0.0007 -19.5535 -5.2848
# ...

# %% [markdown]
# ### Model 5

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 5, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 5
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0307   0.0212 1637.5754 4.0470    4  511   0.0031
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            30.9206 7.1934  4.2985 0.0000  16.8219 45.0194
# ...

# %% [markdown]
# ### Model 8

# %%
p_old = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Spendentafel'], quantile=True)
p_old.summary()

p_new = Process(data = bb_donation_money_spendentafel, model = 8, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Spendentafel'], quantile=True)
p_new.summary()
# Out:
# Process successfully initialized.
# Based on the Process Macro by Andrew F. Hayes, Ph.D. (www.afhayes.com)
#
#
# ****************************** SPECIFICATION ****************************
#
# Model = 8
#
# Variables:
#     Cons = Cons
#     x = StyleGlam0Hippie1
#     y = DonationMoney
#     m1 = SocialStatusOld
#     w = Spendentafel
#
# Sample size:
# 516
#
# Bootstrapping information for indirect effects:
# Final number of bootstrap samples: 5000
# Number of samples discarded due to convergence issues: 0
#
# ***************************** OUTCOME MODELS ****************************
#
# Outcome = DonationMoney
# OLS Regression Summary
#
#      R²  Adj. R²       MSE      F  df1  df2  p-value
#  0.0307   0.0212 1637.5754 4.0470    4  511   0.0031
#
# Coefficients
#
#                                   coeff     se       t      p     LLCI    ULCI
# Cons                            30.9206 7.1934  4.2985 0.0000  16.8219 45.0194
# ...

# %% [markdown]
# ## Donation Money Video

# %% [markdown]
# ### Model 7

# %%
m_d_a_m_df = df[df["Experiment_Type"] == "M_D_A_M"].copy()
m_d_n_m_df = df[df["Experiment_Type"] == "M_D_N_M"].copy()

columnNames = {
    'Social_Status_Old_1_4': 'SocialStatusOld',
    'Social_Status_New_1_7': 'SocialStatusNew',
    'Awe_3cat': 'Video',
    'Style_Glam0_Hippie1': 'StyleGlam0Hippie1', 
}

m_d_a_m_df  = m_d_a_m_df.rename(columns=columnNames)
m_d_n_m_df = m_d_n_m_df.rename(columns=columnNames)
m_d_m_df = m_d_m_df.rename(columns={'Awe_3cat': 'Video'})


vars_needed = [
    'StyleGlam0Hippie1',
    'DonationMoney',
    'SocialStatusOld',
    'SocialStatusNew',
    'Video'
]

mall_donation_money_video_0_1 = (pd.concat([m_d_m_df, m_d_n_m_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_0_2 = (pd.concat([m_d_m_df, m_d_a_m_df], ignore_index=True))[vars_needed].dropna().copy()
mall_donation_money_video_1_2 = (pd.concat([m_d_a_m_df, m_d_n_m_df], ignore_index=True))[vars_needed].dropna().copy()

mall_donation_money_video_0_1.columns.tolist()
mall_donation_money_video_1_2.columns.toList()

for col in mall_donation_money_video_0_1.columns:
    print(f"\n===== Column: {col} =====")
    print("Unique values:")
    print(mall_donation_money_video_0_1[col].unique())

    print("\nValue counts:")
    print(mall_donation_money_video_0_1[col].value_counts(dropna=False))

    print("\n----------------------------")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/14/q6smmykd721g4xgkp2my8d6c0000gn/T/ipykernel_77420/494585403.py in ?()
#      25 mall_donation_money_video_0_2 = (pd.concat([m_d_m_df, m_d_a_m_df], ignore_index=True))[vars_needed].dropna().copy()
#      26 mall_donation_money_video_1_2 = (pd.concat([m_d_a_m_df, m_d_n_m_df], ignore_index=True))[vars_needed].dropna().copy()
#      27
#      28 mall_donation_money_video_0_1.columns.tolist()
# ---> 29 mall_donation_money_video_1_2.toList()
#      30
#      31 for col in mall_donation_money_video_0_1.columns:
#      32     print(f"\n===== Column: {col} =====")
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
# ...

# %%
# No and Neutral

print("..................... NoVideo and Neutral Video, Status Old .....................")
p_old = Process(data = mall_donation_money_video_0_1, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... NoVideo and Neutral Video, Status New .....................")

p_new = Process(data = mall_donation_money_video_0_1, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
# Neutral and Awe

print("..................... No and Awe Video, Status Old .....................")


p_old = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... No and Awe Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_0_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()

# %%
print("..................... Awe and Neutral Video, Status Old .....................")

# No and Awe
p_old = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
p_old.summary()

print("..................... Awe and Neutral Video, Status New .....................")


p_new = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusNew'], w =['Video'], quantile=True)
p_new.summary()
# Out:
# ..................... Awe and Neutral Video, Status Old .....................
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 print("..................... Awe and Neutral Video, Status Old .....................")
#       3 # No and Awe
# ----> 4 p_old = Process(data = mall_donation_money_video_1_2, model = 7, x = 'StyleGlam0Hippie1', y = 'DonationMoney', m = ['SocialStatusOld'], w =['Video'], quantile=True)
#       5 p_old.summary()
#       7 print("..................... Awe and Neutral Video, Status New .....................")
#
# NameError: name 'mall_donation_money_video_1_2' is not defined
