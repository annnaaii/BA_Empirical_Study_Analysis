# %%
#Model 4

import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.utils import resample
import numpy as np

def run_multiple_mediation_analyses_per_condition_glam_base(file_path, mediators, dvs, controls=None):
    results = []

    # 1. Daten laden
    data = pd.read_csv(file_path)
    data["Style"] = data["Style"].map({"Glam": 0, "Hippie": 1})

    # 2. Stelle sicher, dass alle benötigten Spalten numerisch sind
    columns = ["Style"] + mediators + dvs + (controls if controls else [])
    for col in columns:
        data[col] = pd.to_numeric(data[col], errors="coerce")

    # 3. Gültige Controls (ohne NaNs)
    valid_controls = []
    if controls:
        for ctrl in controls:
            if data[ctrl].notna().sum() > 0:
                valid_controls.append(ctrl)

    # 4. Schleife über jede Condition
    for condition, subset in data.groupby("Experiment"):
        for mediator in mediators:
            for dv in dvs:
                required_cols = ["Style", mediator, dv] + valid_controls
                df_clean = subset.dropna(subset=required_cols)
                n = len(df_clean)
                if n < 10:
                    continue  # zu wenige Daten

                control_str = " + " + " + ".join(valid_controls) if valid_controls else ""

                try:
                    # Pfad a
                    a_model = ols(f"{mediator} ~ Style{control_str}", data=df_clean).fit()
                    a = a_model.params["Style"]
                    p_a = a_model.pvalues["Style"]

                    # Pfad b & c'
                    b_model = ols(f"{dv} ~ Style + {mediator}{control_str}", data=df_clean).fit()
                    b = b_model.params[mediator]
                    p_b = b_model.pvalues[mediator]
                    c_prime = b_model.params["Style"]
                    p_c_prime = b_model.pvalues["Style"]

                    # Pfad c
                    c_model = ols(f"{dv} ~ Style{control_str}", data=df_clean).fit()
                    c = c_model.params["Style"]
                    p_c = c_model.pvalues["Style"]

                    ab = a * b

                    # Bootstrap für indirekten Effekt
                    ab_samples = []
                    for _ in range(1000):
                        sample = resample(df_clean)
                        try:
                            a_s = ols(f"{mediator} ~ Style{control_str}", data=sample).fit().params["Style"]
                            b_s = ols(f"{dv} ~ Style + {mediator}{control_str}", data=sample).fit().params[mediator]
                            ab_samples.append(a_s * b_s)
                        except:
                            continue

                    ab_ci = np.percentile(ab_samples, [2.5, 97.5])
                    p_ab = (np.sum(np.array(ab_samples) < 0) if ab > 0 else np.sum(np.array(ab_samples) > 0)) / len(ab_samples) * 2

                    # Ergebnisse speichern
                    results.append({
                        "Condition": condition,
                        "Mediator": mediator,
                        "DV": dv,
                        "n": n,
                        "a": a, "p-value a": p_a,
                        "b": b, "p-value b": p_b,
                        "c'": c_prime, "p-value c'": p_c_prime,
                        "c": c, "p-value c": p_c,
                        "a*b": ab, "p-value a*b": p_ab,
                        "BootLLCI": ab_ci[0],
                        "BootULCI": ab_ci[1]
                    })
                except Exception as e:
                    print(f"Fehler bei {condition}, {mediator}, {dv}: {e}")
                    continue

    return pd.DataFrame(results)


def color_pval(val):
    try:
        val = float(val)
    except:
        return ''
    
    if val < 0.001:
        return 'background-color: #008a00'   # strong dark green
    elif val < 0.01:
        return 'background-color: #2e7d32'   # dark green
    elif val < 0.05:
        return 'background-color: #7cbf7c'   # darker green (was too light before)
    elif val < 0.1:
        return 'background-color: #d4a017'   # dark mustard yellow
    elif val < 0.2:
        return 'background-color: #d28c8c'   # muted dark red
    else:
        return 'background-color: #9e9e9e'   # clearly darker grey


# Beispiel JewelryStore
results_jewelry = run_multiple_mediation_analyses_per_condition_glam_base(
    file_path='../Merging/Results/master_with_dv_means_recoded.csv',
    mediators=["Social_Status_Old_1_3", "Social_Status_New_1_7", 'Egoism', 'Altruism', 'Environmental_Concern'],
    dvs=['DonationMoney'],
    controls=['Age', 'DeutschkenntnisseGutSchlecht', 'GeldProMonatKleidung','GeldProMonat', 'IdentificationOutfit', 'LikingOutfit']
)

# Ergebnis visualisieren
pval_cols = [c for c in results_jewelry.columns if "p-value" in c]
styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
display(styled)
# Out:
# /var/folders/14/q6smmykd721g4xgkp2my8d6c0000gn/T/ipykernel_94466/1623661643.py:125: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
# <style type="text/css">
# #T_ab067_row0_col5, #T_ab067_row0_col13, #T_ab067_row1_col13, #T_ab067_row3_col5, #T_ab067_row3_col13, #T_ab067_row4_col5, #T_ab067_row4_col13, #T_ab067_row5_col7, #T_ab067_row5_col13, #T_ab067_row6_col7, #T_ab067_row6_col13, #T_ab067_row7_col5, #T_ab067_row7_col7, #T_ab067_row7_col13, #T_ab067_row8_col5, #T_ab067_row8_col7, #T_ab067_row8_col13, #T_ab067_row9_col5, #T_ab067_row9_col7, #T_ab067_row9_col13, #T_ab067_row10_col5, #T_ab067_row10_col13, #T_ab067_row12_col5, #T_ab067_row12_col7, #T_ab067_row12_col13, #T_ab067_row13_col5, #T_ab067_row13_col13, #T_ab067_row14_col7, #T_ab067_row14_col13, #T_ab067_row16_col13, #T_ab067_row17_col7, #T_ab067_row17_col13, #T_ab067_row20_col9, #T_ab067_row20_col11, #T_ab067_row21_col9, #T_ab067_row21_col11, #T_ab067_row22_col7, #T_ab067_row22_col9, #T_ab067_row22_col11, #T_ab067_row22_col13, #T_ab067_row23_col9, #T_ab067_row23_col11, #T_ab067_row24_col9, #T_ab067_row24_col11, #T_ab067_row24_col13, #T_ab067_row25_col7, #T_ab067_row25_col13, #T_ab067_row26_col7, #T_ab067_row26_col13, #T_ab067_row27_col5, #T_ab067_row27_col13, #T_ab067_row29_col5, #T_ab067_row29_col7, #T_ab067_row29_col13 {
#   background-color: #9e9e9e;
# }
# #T_ab067_row0_col7, #T_ab067_row0_col9, #T_ab067_row1_col9, #T_ab067_row3_col9, #T_ab067_row4_col9, #T_ab067_row5_col5, #T_ab067_row15_col9, #T_ab067_row16_col9, #T_ab067_row19_col7, #T_ab067_row19_col13, #T_ab067_row23_col7, #T_ab067_row23_col13, #T_ab067_row28_col5 {
#   background-color: #d4a017;
# }
# #T_ab067_row0_col11, #T_ab067_row1_col7, #T_ab067_row1_col11, #T_ab067_row2_col11, #T_ab067_row3_col7, #T_ab067_row3_col11, #T_ab067_row4_col7, #T_ab067_row4_col11, #T_ab067_row6_col5, #T_ab067_row11_col5, #T_ab067_row11_col13, #T_ab067_row13_col7, #T_ab067_row14_col5, #T_ab067_row15_col7, #T_ab067_row15_col13, #T_ab067_row16_col7, #T_ab067_row20_col5, #T_ab067_row20_col13, #T_ab067_row21_col13, #T_ab067_row24_col5, #T_ab067_row24_col7, #T_ab067_row28_col13 {
#   background-color: #d28c8c;
# }
# #T_ab067_row1_col5, #T_ab067_row2_col5, #T_ab067_row2_col7, #T_ab067_row2_col9, #T_ab067_row2_col13, #T_ab067_row5_col9, #T_ab067_row6_col9, #T_ab067_row7_col9, #T_ab067_row8_col9, #T_ab067_row9_col9, #T_ab067_row15_col11, #T_ab067_row16_col11, #T_ab067_row17_col9, #T_ab067_row17_col11, #T_ab067_row18_col5, #T_ab067_row18_col11, #T_ab067_row18_col13, #T_ab067_row19_col9, #T_ab067_row19_col11, #T_ab067_row20_col7, #T_ab067_row21_col5, #T_ab067_row21_col7, #T_ab067_row22_col5, #T_ab067_row25_col5 {
#   background-color: #7cbf7c;
# }
# #T_ab067_row5_col11, #T_ab067_row6_col11, #T_ab067_row7_col11, #T_ab067_row8_col11, #T_ab067_row9_col11, #T_ab067_row10_col7, #T_ab067_row18_col9, #T_ab067_row19_col5, #T_ab067_row23_col5, #T_ab067_row25_col11, #T_ab067_row26_col5, #T_ab067_row26_col11, #T_ab067_row27_col11, #T_ab067_row28_col11, #T_ab067_row29_col9, #T_ab067_row29_col11 {
#   background-color: #2e7d32;
# }
# #T_ab067_row10_col9, #T_ab067_row10_col11, #T_ab067_row11_col7, #T_ab067_row11_col9, #T_ab067_row11_col11, #T_ab067_row12_col9, #T_ab067_row12_col11, #T_ab067_row13_col9, #T_ab067_row13_col11, #T_ab067_row14_col9, #T_ab067_row14_col11, #T_ab067_row15_col5, #T_ab067_row16_col5, #T_ab067_row17_col5, #T_ab067_row18_col7, #T_ab067_row25_col9, #T_ab067_row26_col9, #T_ab067_row27_col7, #T_ab067_row27_col9, #T_ab067_row28_col7, #T_ab067_row28_col9 {
#   background-color: #008a00;
# }
# </style>
# <table id="T_ab067">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab067_level0_col0" class="col_heading level0 col0" >Condition</th>
#       <th id="T_ab067_level0_col1" class="col_heading level0 col1" >Mediator</th>
#       <th id="T_ab067_level0_col2" class="col_heading level0 col2" >DV</th>
#       <th id="T_ab067_level0_col3" class="col_heading level0 col3" >n</th>
#       <th id="T_ab067_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_ab067_level0_col5" class="col_heading level0 col5" >p-value a</th>
#       <th id="T_ab067_level0_col6" class="col_heading level0 col6" >b</th>
#       <th id="T_ab067_level0_col7" class="col_heading level0 col7" >p-value b</th>
#       <th id="T_ab067_level0_col8" class="col_heading level0 col8" >c'</th>
#       <th id="T_ab067_level0_col9" class="col_heading level0 col9" >p-value c'</th>
#       <th id="T_ab067_level0_col10" class="col_heading level0 col10" >c</th>
#       <th id="T_ab067_level0_col11" class="col_heading level0 col11" >p-value c</th>
#       <th id="T_ab067_level0_col12" class="col_heading level0 col12" >a*b</th>
#       <th id="T_ab067_level0_col13" class="col_heading level0 col13" >p-value a*b</th>
#       <th id="T_ab067_level0_col14" class="col_heading level0 col14" >BootLLCI</th>
#       <th id="T_ab067_level0_col15" class="col_heading level0 col15" >BootULCI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab067_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab067_row0_col0" class="data row0 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_ab067_row0_col1" class="data row0 col1" >Social_Status_Old_1_3</td>
#       <td id="T_ab067_row0_col2" class="data row0 col2" >DonationMoney</td>
#       <td id="T_ab067_row0_col3" class="data row0 col3" >96</td>
#       <td id="T_ab067_row0_col4" class="data row0 col4" >-0.259486</td>
#       <td id="T_ab067_row0_col5" class="data row0 col5" >0.218422</td>
#       <td id="T_ab067_row0_col6" class="data row0 col6" >-6.673368</td>
#       <td id="T_ab067_row0_col7" class="data row0 col7" >0.087891</td>
#       <td id="T_ab067_row0_col8" class="data row0 col8" >-14.145876</td>
#       <td id="T_ab067_row0_col9" class="data row0 col9" >0.068127</td>
#       <td id="T_ab067_row0_col10" class="data row0 col10" >-12.414230</td>
#       <td id="T_ab067_row0_col11" class="data row0 col11" >0.109452</td>
#       <td id="T_ab067_row0_col12" class="data row0 col12" >1.731646</td>
#       <td id="T_ab067_row0_col13" class="data row0 col13" >0.308000</td>
#       <td id="T_ab067_row0_col14" class="data row0 col14" >-1.325954</td>
#       <td id="T_ab067_row0_col15" class="data row0 col15" >5.932794</td>
#     </tr>
#     <tr>
#       <th id="T_ab067_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ab067_row1_col0" class="data row1 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_ab067_row1_col1" class="data row1 col1" >Social_Status_New_1_7</td>
#       <td id="T_ab067_row1_col2" class="data row1 col2" >DonationMoney</td>
#       <td id="T_ab067_row1_col3" class="data row1 col3" >96</td>
#       <td id="T_ab067_row1_col4" class="data row1 col4" >-0.427693</td>
#       <td id="T_ab067_row1_col5" class="data row1 col5" >0.028269</td>
#       <td id="T_ab067_row1_col6" class="data row1 col6" >-6.464280</td>
#       <td id="T_ab067_row1_col7" class="data row1 col7" >0.130617</td>
#       <td id="T_ab067_row1_col8" class="data row1 col8" >-15.178958</td>
#       <td id="T_ab067_row1_col9" class="data row1 col9" >0.055866</td>
#       <td id="T_ab067_row1_col10" class="data row1 col10" >-12.414230</td>
#       <td id="T_ab067_row1_col11" class="data row1 col11" >0.109452</td>
#       <td id="T_ab067_row1_col12" class="data row1 col12" >2.764728</td>
#       <td id="T_ab067_row1_col13" class="data row1 col13" >0.232000</td>
#       <td id="T_ab067_row1_col14" class="data row1 col14" >-1.610788</td>
#       <td id="T_ab067_row1_col15" class="data row1 col15" >8.208946</td>
#     </tr>
#     <tr>
#       <th id="T_ab067_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ab067_row2_col0" class="data row2 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_ab067_row2_col1" class="data row2 col1" >Egoism</td>
#       <td id="T_ab067_row2_col2" class="data row2 col2" >DonationMoney</td>
#       <td id="T_ab067_row2_col3" class="data row2 col3" >96</td>
#       <td id="T_ab067_row2_col4" class="data row2 col4" >-0.391128</td>
#       <td id="T_ab067_row2_col5" class="data row2 col5" >0.016033</td>
#       <td id="T_ab067_row2_col6" class="data row2 col6" >-13.012195</td>
#       <td id="T_ab067_row2_col7" clas

# %%
#Model 4

import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.utils import resample
import numpy as np

def run_multiple_mediation_analyses_per_condition_hippie_base(file_path, mediators, dvs, controls=None):
    results = []

    # 1. Daten laden
    data = pd.read_csv(file_path)
    data["Style"] = data["Style"].map({"Glam": 1, "Hippie": 0})

    # 2. Stelle sicher, dass alle benötigten Spalten numerisch sind
    columns = ["Style"] + mediators + dvs + (controls if controls else [])
    for col in columns:
        data[col] = pd.to_numeric(data[col], errors="coerce")

    # 3. Gültige Controls (ohne NaNs)
    valid_controls = []
    if controls:
        for ctrl in controls:
            if data[ctrl].notna().sum() > 0:
                valid_controls.append(ctrl)

    # 4. Schleife über jede Condition
    for condition, subset in data.groupby("Experiment"):
        for mediator in mediators:
            for dv in dvs:
                required_cols = ["Style", mediator, dv] + valid_controls
                df_clean = subset.dropna(subset=required_cols)
                n = len(df_clean)
                if n < 10:
                    continue  # zu wenige Daten

                control_str = " + " + " + ".join(valid_controls) if valid_controls else ""

                try:
                    # Pfad a
                    a_model = ols(f"{mediator} ~ Style{control_str}", data=df_clean).fit()
                    a = a_model.params["Style"]
                    p_a = a_model.pvalues["Style"]

                    # Pfad b & c'
                    b_model = ols(f"{dv} ~ Style + {mediator}{control_str}", data=df_clean).fit()
                    b = b_model.params[mediator]
                    p_b = b_model.pvalues[mediator]
                    c_prime = b_model.params["Style"]
                    p_c_prime = b_model.pvalues["Style"]

                    # Pfad c
                    c_model = ols(f"{dv} ~ Style{control_str}", data=df_clean).fit()
                    c = c_model.params["Style"]
                    p_c = c_model.pvalues["Style"]

                    ab = a * b

                    # Bootstrap für indirekten Effekt
                    ab_samples = []
                    for _ in range(1000):
                        sample = resample(df_clean)
                        try:
                            a_s = ols(f"{mediator} ~ Style{control_str}", data=sample).fit().params["Style"]
                            b_s = ols(f"{dv} ~ Style + {mediator}{control_str}", data=sample).fit().params[mediator]
                            ab_samples.append(a_s * b_s)
                        except:
                            continue

                    ab_ci = np.percentile(ab_samples, [2.5, 97.5])
                    p_ab = (np.sum(np.array(ab_samples) < 0) if ab > 0 else np.sum(np.array(ab_samples) > 0)) / len(ab_samples) * 2

                    # Ergebnisse speichern
                    results.append({
                        "Condition": condition,
                        "Mediator": mediator,
                        "DV": dv,
                        "n": n,
                        "a": a, "p-value a": p_a,
                        "b": b, "p-value b": p_b,
                        "c'": c_prime, "p-value c'": p_c_prime,
                        "c": c, "p-value c": p_c,
                        "a*b": ab, "p-value a*b": p_ab,
                        "BootLLCI": ab_ci[0],
                        "BootULCI": ab_ci[1]
                    })
                except Exception as e:
                    print(f"Fehler bei {condition}, {mediator}, {dv}: {e}")
                    continue

    return pd.DataFrame(results)


def color_pval(val):
    try:
        val = float(val)
    except:
        return ''
    
    if val < 0.001:
        return 'background-color: #008a00'   # strong dark green
    elif val < 0.01:
        return 'background-color: #2e7d32'   # dark green
    elif val < 0.05:
        return 'background-color: #7cbf7c'   # darker green (was too light before)
    elif val < 0.1:
        return 'background-color: #d4a017'   # dark mustard yellow
    elif val < 0.2:
        return 'background-color: #d28c8c'   # muted dark red
    else:
        return 'background-color: #9e9e9e'   # clearly darker grey


# Beispiel JewelryStore
results_jewelry = run_multiple_mediation_analyses_per_condition_hippie_base(
    file_path='../Merging/Results/master_with_dv_means_recoded.csv',
    mediators=["Social_Status_Old_1_3", "Social_Status_New_1_7", 'Egoism', 'Altruism', 'Environmental_Concern'],
    dvs=['DonationTime'],
    controls=['Age', 'DeutschkenntnisseGutSchlecht', 'GeldProMonatKleidung','GeldProMonat', 'IdentificationOutfit', 'LikingOutfit']
)

# Ergebnis visualisieren
pval_cols = [c for c in results_jewelry.columns if "p-value" in c]
styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
display(styled)
# Out:
# /var/folders/14/q6smmykd721g4xgkp2my8d6c0000gn/T/ipykernel_94466/2981577437.py:125: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
# <style type="text/css">
# #T_6a756_row0_col5, #T_6a756_row3_col5, #T_6a756_row4_col5, #T_6a756_row8_col5, #T_6a756_row12_col5, #T_6a756_row12_col13, #T_6a756_row14_col5, #T_6a756_row14_col13, #T_6a756_row19_col7, #T_6a756_row21_col5, #T_6a756_row27_col9, #T_6a756_row27_col13 {
#   background-color: #d28c8c;
# }
# #T_6a756_row0_col7, #T_6a756_row0_col9, #T_6a756_row0_col11, #T_6a756_row0_col13, #T_6a756_row1_col7, #T_6a756_row1_col9, #T_6a756_row1_col11, #T_6a756_row1_col13, #T_6a756_row2_col5, #T_6a756_row2_col9, #T_6a756_row2_col11, #T_6a756_row2_col13, #T_6a756_row3_col7, #T_6a756_row3_col9, #T_6a756_row3_col11, #T_6a756_row3_col13, #T_6a756_row4_col7, #T_6a756_row4_col9, #T_6a756_row4_col11, #T_6a756_row4_col13, #T_6a756_row5_col5, #T_6a756_row5_col7, #T_6a756_row5_col9, #T_6a756_row5_col11, #T_6a756_row5_col13, #T_6a756_row6_col5, #T_6a756_row6_col7, #T_6a756_row6_col9, #T_6a756_row6_col11, #T_6a756_row6_col13, #T_6a756_row7_col5, #T_6a756_row7_col9, #T_6a756_row7_col11, #T_6a756_row7_col13, #T_6a756_row8_col7, #T_6a756_row8_col9, #T_6a756_row8_col11, #T_6a756_row8_col13, #T_6a756_row9_col5, #T_6a756_row9_col9, #T_6a756_row9_col11, #T_6a756_row9_col13, #T_6a756_row10_col7, #T_6a756_row10_col9, #T_6a756_row10_col11, #T_6a756_row10_col13, #T_6a756_row11_col7, #T_6a756_row11_col9, #T_6a756_row11_col11, #T_6a756_row11_col13, #T_6a756_row12_col9, #T_6a756_row12_col11, #T_6a756_row13_col5, #T_6a756_row13_col9, #T_6a756_row13_col11, #T_6a756_row13_col13, #T_6a756_row14_col9, #T_6a756_row14_col11, #T_6a756_row15_col9, #T_6a756_row15_col11, #T_6a756_row16_col9, #T_6a756_row16_col11, #T_6a756_row17_col7, #T_6a756_row17_col9, #T_6a756_row17_col11, #T_6a756_row17_col13, #T_6a756_row18_col11, #T_6a756_row19_col5, #T_6a756_row19_col9, #T_6a756_row19_col11, #T_6a756_row19_col13, #T_6a756_row20_col5, #T_6a756_row20_col9, #T_6a756_row20_col11, #T_6a756_row20_col13, #T_6a756_row21_col7, #T_6a756_row21_col9, #T_6a756_row21_col11, #T_6a756_row21_col13, #T_6a756_row22_col5, #T_6a756_row22_col7, #T_6a756_row22_col9, #T_6a756_row22_col11, #T_6a756_row22_col13, #T_6a756_row23_col5, #T_6a756_row23_col9, #T_6a756_row23_col11, #T_6a756_row23_col13, #T_6a756_row24_col9, #T_6a756_row24_col11, #T_6a756_row25_col7, #T_6a756_row25_col13, #T_6a756_row26_col7, #T_6a756_row26_col13, #T_6a756_row28_col9, #T_6a756_row29_col9 {
#   background-color: #9e9e9e;
# }
# #T_6a756_row1_col5, #T_6a756_row7_col7, #T_6a756_row18_col9, #T_6a756_row20_col7, #T_6a756_row25_col9, #T_6a756_row25_col11, #T_6a756_row26_col9, #T_6a756_row26_col11, #T_6a756_row27_col7, #T_6a756_row27_col11, #T_6a756_row28_col11, #T_6a756_row29_col11 {
#   background-color: #d4a017;
# }
# #T_6a756_row2_col7, #T_6a756_row10_col5, #T_6a756_row11_col5, #T_6a756_row12_col7, #T_6a756_row15_col7, #T_6a756_row25_col5 {
#   background-color: #2e7d32;
# }
# #T_6a756_row9_col7, #T_6a756_row14_col7, #T_6a756_row15_col5, #T_6a756_row15_col13, #T_6a756_row16_col5, #T_6a756_row16_col7, #T_6a756_row16_col13, #T_6a756_row17_col5, #T_6a756_row18_col5, #T_6a756_row18_col13, #T_6a756_row24_col5, #T_6a756_row24_col13, #T_6a756_row28_col5, #T_6a756_row28_col13, #T_6a756_row29_col5, #T_6a756_row29_col13 {
#   background-color: #7cbf7c;
# }
# #T_6a756_row13_col7, #T_6a756_row18_col7, #T_6a756_row23_col7, #T_6a756_row24_col7, #T_6a756_row26_col5, #T_6a756_row27_col5, #T_6a756_row28_col7, #T_6a756_row29_col7 {
#   background-color: #008a00;
# }
# </style>
# <table id="T_6a756">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a756_level0_col0" class="col_heading level0 col0" >Condition</th>
#       <th id="T_6a756_level0_col1" class="col_heading level0 col1" >Mediator</th>
#       <th id="T_6a756_level0_col2" class="col_heading level0 col2" >DV</th>
#       <th id="T_6a756_level0_col3" class="col_heading level0 col3" >n</th>
#       <th id="T_6a756_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_6a756_level0_col5" class="col_heading level0 col5" >p-value a</th>
#       <th id="T_6a756_level0_col6" class="col_heading level0 col6" >b</th>
#       <th id="T_6a756_level0_col7" class="col_heading level0 col7" >p-value b</th>
#       <th id="T_6a756_level0_col8" class="col_heading level0 col8" >c'</th>
#       <th id="T_6a756_level0_col9" class="col_heading level0 col9" >p-value c'</th>
#       <th id="T_6a756_level0_col10" class="col_heading level0 col10" >c</th>
#       <th id="T_6a756_level0_col11" class="col_heading level0 col11" >p-value c</th>
#       <th id="T_6a756_level0_col12" class="col_heading level0 col12" >a*b</th>
#       <th id="T_6a756_level0_col13" class="col_heading level0 col13" >p-value a*b</th>
#       <th id="T_6a756_level0_col14" class="col_heading level0 col14" >BootLLCI</th>
#       <th id="T_6a756_level0_col15" class="col_heading level0 col15" >BootULCI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a756_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a756_row0_col0" class="data row0 col0" >21_BeachBar_Trash_Donation_SpendentafelTime</td>
#       <td id="T_6a756_row0_col1" class="data row0 col1" >Social_Status_Old_1_3</td>
#       <td id="T_6a756_row0_col2" class="data row0 col2" >DonationTime</td>
#       <td id="T_6a756_row0_col3" class="data row0 col3" >63</td>
#       <td id="T_6a756_row0_col4" class="data row0 col4" >0.334024</td>
#       <td id="T_6a756_row0_col5" class="data row0 col5" >0.191663</td>
#       <td id="T_6a756_row0_col6" class="data row0 col6" >3.823699</td>
#       <td id="T_6a756_row0_col7" class="data row0 col7" >0.540479</td>
#       <td id="T_6a756_row0_col8" class="data row0 col8" >-7.008229</td>
#       <td id="T_6a756_row0_col9" class="data row0 col9" >0.555555</td>
#       <td id="T_6a756_row0_col10" class="data row0 col10" >-5.731023</td>
#       <td id="T_6a756_row0_col11" class="data row0 col11" >0.622219</td>
#       <td id="T_6a756_row0_col12" class="data row0 col12" >1.277207</td>
#       <td id="T_6a756_row0_col13" class="data row0 col13" >0.608000</td>
#       <td id="T_6a756_row0_col14" class="data row0 col14" >-3.634385</td>
#       <td id="T_6a756_row0_col15" class="data row0 col15" >8.712967</td>
#     </tr>
#     <tr>
#       <th id="T_6a756_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a756_row1_col0" class="data row1 col0" >21_BeachBar_Trash_Donation_SpendentafelTime</td>
#       <td id="T_6a756_row1_col1" class="data row1 col1" >Social_Status_New_1_7</td>
#       <td id="T_6a756_row1_col2" class="data row1 col2" >DonationTime</td>
#       <td id="T_6a756_row1_col3" class="data row1 col3" >63</td>
#       <td id="T_6a756_row1_col4" class="data row1 col4" >0.491579</td>
#       <td id="T_6a756_row1_col5" class="data row1 col5" >0.056300</td>
#       <td id="T_6a756_row1_col6" class="data row1 col6" >-7.273199</td>
#       <td id="T_6a756_row1_col7" class="data row1 col7" >0.243198</td>
#       <td id="T_6a756_row1_col8" class="data row1 col8" >-2.155670</td>
#       <td id="T_6a756_row1_col9" class="data row1 col9" >0.857127</td>
#       <td id="T_6a756_row1_col10" class="data row1 col10" >-5.731023</td>
#       <td id="T_6a756_row1_col11" class="data row1 col11" >0.622219</td>
#       <td id="T_6a756_row1_col12" class="data row1 col12" >-3.575353</td>
#       <td id="T_6a756_row1_col13" class="data row1 col13" >0.318000</td>
#       <td id="T_6a756_row1_col14" class="data row1 col14" >-12.811840</td>
#       <td id="T_6a756_row1_col15" class="data row1 col15" >2.802086</td>
#     </tr>
#     <tr>
#       <th id="T_6a756_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a756_row2_col0" class="data row2 col0" >21_BeachBar_Trash_Donation_SpendentafelTime</td>
#       <td id="T_6a756_row2_col1" class="data row2 col1" >Egoism</td>
#       <td id="T_6a756_row2_col2" class="data row2 col2" >DonationTime</td>
#       <td id="T_6a756_row2_col3" class="data row2 col3" >63</td>
#       <td id="T_6a756_row2_col4" class="data row2 col4" >0.255991</td>
#       <td id="T_6a756_row2_col5" class="data row2 col5" >0.205562</td>
#       <td id="T_6a756_row2_col6" class="data row2 col6" >-22.465849</td>
#       <td id=

# %%
#Model 4

import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.utils import resample
import numpy as np

# Beispiel JewelryStore
results_jewelry = run_multiple_mediation_analyses_per_condition_hippie_base(
    file_path='../Merging/Results/master_with_dv_means_recoded.csv',
    mediators=["Social_Status_Old_1_3", "Social_Status_New_1_7", 'Egoism', 'Altruism', 'Environmental_Concern'],
    dvs=['trashCount'],
    controls=['Age', 'DeutschkenntnisseGutSchlecht', 'GeldProMonatKleidung','GeldProMonat', 'IdentificationOutfit', 'LikingOutfit']
)

# Ergebnis visualisieren
pval_cols = [c for c in results_jewelry.columns if "p-value" in c]
styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
display(styled)
# Out:
# /var/folders/14/q6smmykd721g4xgkp2my8d6c0000gn/T/ipykernel_94466/3005582378.py:19: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled = results_jewelry.style.applymap(color_pval, subset=pval_cols)
# <style type="text/css">
# #T_2b9ce_row0_col5, #T_2b9ce_row0_col7, #T_2b9ce_row0_col9, #T_2b9ce_row0_col11, #T_2b9ce_row0_col13, #T_2b9ce_row1_col7, #T_2b9ce_row1_col9, #T_2b9ce_row1_col11, #T_2b9ce_row1_col13, #T_2b9ce_row2_col7, #T_2b9ce_row2_col9, #T_2b9ce_row2_col11, #T_2b9ce_row2_col13, #T_2b9ce_row3_col5, #T_2b9ce_row3_col7, #T_2b9ce_row3_col9, #T_2b9ce_row3_col11, #T_2b9ce_row3_col13, #T_2b9ce_row4_col5, #T_2b9ce_row4_col7, #T_2b9ce_row4_col9, #T_2b9ce_row4_col11, #T_2b9ce_row4_col13, #T_2b9ce_row5_col7, #T_2b9ce_row5_col13, #T_2b9ce_row6_col7, #T_2b9ce_row6_col13, #T_2b9ce_row7_col5, #T_2b9ce_row7_col7, #T_2b9ce_row7_col13, #T_2b9ce_row8_col5, #T_2b9ce_row8_col7, #T_2b9ce_row8_col13, #T_2b9ce_row9_col5, #T_2b9ce_row9_col7, #T_2b9ce_row9_col13, #T_2b9ce_row10_col7, #T_2b9ce_row10_col9, #T_2b9ce_row10_col11, #T_2b9ce_row10_col13, #T_2b9ce_row11_col7, #T_2b9ce_row11_col9, #T_2b9ce_row11_col11, #T_2b9ce_row11_col13, #T_2b9ce_row12_col5, #T_2b9ce_row12_col9, #T_2b9ce_row12_col11, #T_2b9ce_row12_col13, #T_2b9ce_row13_col7, #T_2b9ce_row13_col9, #T_2b9ce_row13_col11, #T_2b9ce_row13_col13, #T_2b9ce_row14_col7, #T_2b9ce_row14_col9, #T_2b9ce_row14_col11, #T_2b9ce_row14_col13, #T_2b9ce_row15_col5, #T_2b9ce_row15_col7, #T_2b9ce_row15_col9, #T_2b9ce_row15_col11, #T_2b9ce_row15_col13, #T_2b9ce_row16_col5, #T_2b9ce_row16_col7, #T_2b9ce_row16_col9, #T_2b9ce_row16_col11, #T_2b9ce_row16_col13, #T_2b9ce_row17_col5, #T_2b9ce_row17_col7, #T_2b9ce_row17_col9, #T_2b9ce_row17_col11, #T_2b9ce_row17_col13, #T_2b9ce_row18_col7, #T_2b9ce_row18_col9, #T_2b9ce_row18_col11, #T_2b9ce_row18_col13, #T_2b9ce_row19_col5, #T_2b9ce_row19_col7, #T_2b9ce_row19_col9, #T_2b9ce_row19_col11, #T_2b9ce_row19_col13, #T_2b9ce_row20_col5, #T_2b9ce_row20_col7, #T_2b9ce_row20_col9, #T_2b9ce_row20_col11, #T_2b9ce_row20_col13, #T_2b9ce_row21_col7, #T_2b9ce_row21_col9, #T_2b9ce_row21_col11, #T_2b9ce_row21_col13, #T_2b9ce_row22_col5, #T_2b9ce_row22_col7, #T_2b9ce_row22_col9, #T_2b9ce_row22_col11, #T_2b9ce_row22_col13, #T_2b9ce_row23_col9, #T_2b9ce_row23_col11, #T_2b9ce_row24_col5, #T_2b9ce_row24_col7, #T_2b9ce_row24_col9, #T_2b9ce_row24_col11, #T_2b9ce_row24_col13, #T_2b9ce_row25_col9, #T_2b9ce_row25_col11, #T_2b9ce_row25_col13, #T_2b9ce_row26_col5, #T_2b9ce_row26_col7, #T_2b9ce_row26_col11, #T_2b9ce_row26_col13, #T_2b9ce_row27_col9, #T_2b9ce_row27_col11, #T_2b9ce_row28_col7, #T_2b9ce_row28_col9, #T_2b9ce_row28_col11, #T_2b9ce_row28_col13, #T_2b9ce_row29_col7, #T_2b9ce_row29_col9, #T_2b9ce_row29_col11, #T_2b9ce_row29_col13, #T_2b9ce_row30_col5, #T_2b9ce_row30_col7, #T_2b9ce_row30_col9, #T_2b9ce_row30_col11, #T_2b9ce_row30_col13, #T_2b9ce_row31_col5, #T_2b9ce_row31_col9, #T_2b9ce_row31_col11, #T_2b9ce_row31_col13 {
#   background-color: #9e9e9e;
# }
# #T_2b9ce_row1_col5, #T_2b9ce_row2_col5, #T_2b9ce_row21_col5, #T_2b9ce_row23_col5, #T_2b9ce_row28_col5, #T_2b9ce_row29_col5 {
#   background-color: #7cbf7c;
# }
# #T_2b9ce_row5_col5, #T_2b9ce_row5_col9, #T_2b9ce_row5_col11, #T_2b9ce_row6_col11, #T_2b9ce_row7_col11, #T_2b9ce_row8_col11, #T_2b9ce_row9_col11, #T_2b9ce_row11_col5, #T_2b9ce_row23_col7, #T_2b9ce_row27_col5, #T_2b9ce_row27_col7, #T_2b9ce_row27_col13, #T_2b9ce_row31_col7 {
#   background-color: #d4a017;
# }
# #T_2b9ce_row6_col5, #T_2b9ce_row6_col9, #T_2b9ce_row7_col9, #T_2b9ce_row8_col9, #T_2b9ce_row9_col9, #T_2b9ce_row10_col5, #T_2b9ce_row12_col7, #T_2b9ce_row13_col5, #T_2b9ce_row14_col5, #T_2b9ce_row18_col5, #T_2b9ce_row23_col13, #T_2b9ce_row25_col5, #T_2b9ce_row25_col7, #T_2b9ce_row26_col9 {
#   background-color: #d28c8c;
# }
# </style>
# <table id="T_2b9ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b9ce_level0_col0" class="col_heading level0 col0" >Condition</th>
#       <th id="T_2b9ce_level0_col1" class="col_heading level0 col1" >Mediator</th>
#       <th id="T_2b9ce_level0_col2" class="col_heading level0 col2" >DV</th>
#       <th id="T_2b9ce_level0_col3" class="col_heading level0 col3" >n</th>
#       <th id="T_2b9ce_level0_col4" class="col_heading level0 col4" >a</th>
#       <th id="T_2b9ce_level0_col5" class="col_heading level0 col5" >p-value a</th>
#       <th id="T_2b9ce_level0_col6" class="col_heading level0 col6" >b</th>
#       <th id="T_2b9ce_level0_col7" class="col_heading level0 col7" >p-value b</th>
#       <th id="T_2b9ce_level0_col8" class="col_heading level0 col8" >c'</th>
#       <th id="T_2b9ce_level0_col9" class="col_heading level0 col9" >p-value c'</th>
#       <th id="T_2b9ce_level0_col10" class="col_heading level0 col10" >c</th>
#       <th id="T_2b9ce_level0_col11" class="col_heading level0 col11" >p-value c</th>
#       <th id="T_2b9ce_level0_col12" class="col_heading level0 col12" >a*b</th>
#       <th id="T_2b9ce_level0_col13" class="col_heading level0 col13" >p-value a*b</th>
#       <th id="T_2b9ce_level0_col14" class="col_heading level0 col14" >BootLLCI</th>
#       <th id="T_2b9ce_level0_col15" class="col_heading level0 col15" >BootULCI</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b9ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b9ce_row0_col0" class="data row0 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_2b9ce_row0_col1" class="data row0 col1" >Social_Status_Old_1_3</td>
#       <td id="T_2b9ce_row0_col2" class="data row0 col2" >trashCount</td>
#       <td id="T_2b9ce_row0_col3" class="data row0 col3" >96</td>
#       <td id="T_2b9ce_row0_col4" class="data row0 col4" >0.259486</td>
#       <td id="T_2b9ce_row0_col5" class="data row0 col5" >0.218422</td>
#       <td id="T_2b9ce_row0_col6" class="data row0 col6" >-1.745042</td>
#       <td id="T_2b9ce_row0_col7" class="data row0 col7" >0.628887</td>
#       <td id="T_2b9ce_row0_col8" class="data row0 col8" >-3.564314</td>
#       <td id="T_2b9ce_row0_col9" class="data row0 col9" >0.618243</td>
#       <td id="T_2b9ce_row0_col10" class="data row0 col10" >-4.017128</td>
#       <td id="T_2b9ce_row0_col11" class="data row0 col11" >0.569415</td>
#       <td id="T_2b9ce_row0_col12" class="data row0 col12" >-0.452814</td>
#       <td id="T_2b9ce_row0_col13" class="data row0 col13" >0.712000</td>
#       <td id="T_2b9ce_row0_col14" class="data row0 col14" >-2.872852</td>
#       <td id="T_2b9ce_row0_col15" class="data row0 col15" >2.504841</td>
#     </tr>
#     <tr>
#       <th id="T_2b9ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b9ce_row1_col0" class="data row1 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_2b9ce_row1_col1" class="data row1 col1" >Social_Status_New_1_7</td>
#       <td id="T_2b9ce_row1_col2" class="data row1 col2" >trashCount</td>
#       <td id="T_2b9ce_row1_col3" class="data row1 col3" >96</td>
#       <td id="T_2b9ce_row1_col4" class="data row1 col4" >0.427693</td>
#       <td id="T_2b9ce_row1_col5" class="data row1 col5" >0.028269</td>
#       <td id="T_2b9ce_row1_col6" class="data row1 col6" >-1.023786</td>
#       <td id="T_2b9ce_row1_col7" class="data row1 col7" >0.795159</td>
#       <td id="T_2b9ce_row1_col8" class="data row1 col8" >-3.579262</td>
#       <td id="T_2b9ce_row1_col9" class="data row1 col9" >0.623686</td>
#       <td id="T_2b9ce_row1_col10" class="data row1 col10" >-4.017128</td>
#       <td id="T_2b9ce_row1_col11" class="data row1 col11" >0.569415</td>
#       <td id="T_2b9ce_row1_col12" class="data row1 col12" >-0.437866</td>
#       <td id="T_2b9ce_row1_col13" class="data row1 col13" >0.786000</td>
#       <td id="T_2b9ce_row1_col14" class="data row1 col14" >-3.869783</td>
#       <td id="T_2b9ce_row1_col15" class="data row1 col15" >3.460150</td>
#     </tr>
#     <tr>
#       <th id="T_2b9ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b9ce_row2_col0" class="data row2 col0" >21_BeachBar_Trash_Donation_Money</td>
#       <td id="T_2b9ce_row2_col1" class="data row2 col1" >Egoism</td>
#       <td id="T_2b9ce_row2_col2" class="data row2 col2" >trashCount</td>
#       <td id="T_2b9ce_row2_col3" class="data row2 col3" >96</td>
#       <td id="T_2b9ce_row2_col4" class="data row2 col4" >0.391128</td>
#       <td id="T_2b9ce_row2_col5" class="data
